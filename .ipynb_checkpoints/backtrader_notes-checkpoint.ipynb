# %% [markdown]
# # Testing Backtrader with SMA, EMA, BB and RSI Strategy Classes

# %%
#import the necessary dependencies
import backtrader as bt 
import datetime
import os
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Learning BackTrader Strategy Blueprint

# %% [markdown]
# ### Notes:
# - self.datas is a list that stores the different data feeds added to the Cerebro engine.
# self.datas[0] refers to the first (or primary) data feed. If you add multiple data feeds, they would be indexed as self.datas[1], self.datas[2], and so on.
#
# - self.dataclose = self.datas[0].close assigns the closing price series to self.dataclose.
#
# - If you did self.dataopen = self.datas[0].open, you would be able to access the opening prices as well
#
# #### Self.dataclose:
# - self.dataclose[0] refers to the current bar's closing price (the latest one in the iteration).
# - self.dataclose[-1] refers to the previous bar's closing price.
# - self.dataclose[-2] refers to the closing price two bars ago, and so on.
# - self.dataclose is not a list that is appended to, but rather a time-series reference that shifts automatically with each iteration.
#
# #### How BackTrader Works:
# - self.datas[0] is the primary data feed and given the csv file or any other method of data, it will iterate over it one by one assigning the current row to self.datas[0] and then you can access the open, high, low, close and other metrics depending on the data.
# - Then, using this, you can assign values to variables in the init method for a given iteration which will change in the later iterations.
# - After the values are assigned, backtrader will execute the next method which includes all of the trading logic and then move onto the next interation with the next row of the datafeed and now that becomes the new value for self.datas[0]
#
# #### Order Class:
# - keep in mind that the order passed into the notify_order method is different from self.order
# - self.order keeps track of pending orders whereas order is an instance of the Order class which sits in the parent bt.Strategy class.
# - order object has a lot of methods including order.executed.price which returns the executed price and the others ones as shown in the code below

# %%
#bt.Strategy is a parent class of this child class which is a Strategy the user creates 
class TestStrategy(bt.Strategy):

    params = (
        ('exitbars', 5),
        ('sma_slow_period', 100),
        ('sma_fast_period', 50),
    )
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    # this method initializes all of the instance variables
    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # need a variable that keeps track of pending orders
        # all orders that have not been completed or accepted are stores in self.order
        self.order = None 

        # we want to see the buy price and the commision for each trade as well; these are only for logging purposes
        self.buyprice = None
        self.buycomm = None

        #if you want to add any indicators, you can add them in the init method
        self.sma = bt.indicators.SimpleMovingAverage(self.datas[0], 
                                                     period = self.params.sma_slow_period)

    def notify_order(self, order):

        # means that the order has been submitted or accepted by the broker in which case there is nothing to do
        if order.status in [order.Submitted, order.Accepted]:
            return

        # now we must check if the order has been completed
        # note: the broker can reject the order due to insufficient cash

        if order.status in [order.Completed]:

            # if the order has been completed, we now just have to log it and the log will be different depending on if the order is a buy or sell

            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                
            elif order.issell():
                self.log(
                    'SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
            # now for this strategy, we need to keep in mind the bar at which the order was executed which we can create an instance variable for
            # now because self is an iterable object that goes through the entire dataset, the length of self will be the number of rows 
            # it has traversed. So if it is on row number 10, that means len(self) will return 10 and since we are looking at daily chart 
            # values, it means 10 days since the backtest started
            self.bar_executed = len(self)
        
        #now we must deal with the case where the order is rejected
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')


        # there are no pending orders at the moment but they would be appended to this object in the next() method
        # since all of the order logic has been handles above, at the moment, there are no pending orders so set equal to None
        self.order = None


    def notify_trade(self, trade):

        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    # all trading logic goes in here
    # for this test program, we buy if the current price is lower than previous price and if previous price is lower than its previous price
    # we sell in 5 days no matter what
    def next(self):
        # Simply log the closing price of the series from the reference

        self.log('Close, %.2f' % self.dataclose[0])
        
        if self.order:

            #you dont want to place an order if there is already an order that is pending
            return

        #check to make sure we are not currently in a position
        if not self.position:

            if self.dataclose[0] < self.dataclose[-1]:
    
                if self.dataclose[-1] < self.dataclose[-2]:
    
                    #essentially just calling the log method and logging the current price at which the buy order was created
                    self.log('CREATE BUY ORDER, %.2f' % self.dataclose[0])

                    #the order variable is set to the buy order
                    self.order = self.buy()
        else:
            #if the current self object is 5 days or more ahead of the last bar where an order was executed
            if len(self) >= (self.bar_executed + self.params.exitbars):

                self.log('CREATE SELl ORDER, %.2f' % self.dataclose[0])
                self.order = self.sell()

# %% [markdown]
# ### Make the Backtesting Engine

# %%
#cerebro is like the brains of backtrader as it provides the live feeds and connects strategy to backtesting framework
cerebro = bt.Cerebro()

# Add a strategy
cerebro.addstrategy(TestStrategy)

#set starting cash values
cerebro.broker.setcash(1000000.0)

modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
modpath, _ = modpath.split(r'/venv')
datapath = os.path.join(modpath, 'data_folder/nvda-1999-2014.txt')

# Create a Data Feed
data = bt.feeds.YahooFinanceCSVData(dataname=datapath, fromdate=datetime.datetime(1999, 1, 25), todate=datetime.datetime(2010, 4, 20),
                                    reverse=False)

# for a more realistic backtest, set the commission to 0.1% per trade
cerebro.broker.setcommission(commission=0.001)

# Add a FixedSize sizer according to the stake; says that 10 shares should be bought per trade
cerebro.addsizer(bt.sizers.FixedSize, stake=10)

# Add the Data Feed to Cerebro
cerebro.adddata(data)

print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

cerebro.run()
# Out:
# Starting Portfolio Value: 1000000.00
# 1999-06-16, Close, 1.35
# 1999-06-17, Close, 1.31
# 1999-06-18, Close, 1.26
# 1999-06-18, CREATE BUY ORDER, 1.26
# 1999-06-21, BUY EXECUTED, Price: 1.30, Cost: 13.00, Comm 0.01
# 1999-06-21, Close, 1.33
# 1999-06-22, Close, 1.31
# 1999-06-23, Close, 1.33
# 1999-06-24, Close, 1.30
# 1999-06-25, Close, 1.32
# 1999-06-28, Close, 1.34
# 1999-06-28, CREATE SELl ORDER, 1.34
# 1999-06-29, SELL EXECUTED, Price: 1.36, Cost: 13.00, Comm 0.01
# 1999-06-29, OPERATION PROFIT, GROSS 0.60, NET 0.57
# 1999-06-29, Close, 1.35
# 1999-06-30, Close, 1.48
# 1999-07-01, Close, 1.40
# 1999-07-02, Close, 1.50
# 1999-07-06, Close, 1.50
# 1999-07-07, Close, 1.48
# 1999-07-08, Close, 1.51
# 1999-07-09, Close, 1.64
# 1999-07-12, Close, 1.71
# 1999-07-13, Close, 1.72
# 1999-07-14, Close, 1.65
# 1999-07-15, Close, 1.66
# 1999-07-16, Close, 1.69
# 1999-07-19, Close, 1.65
# 1999-07-20, Close, 1.62
# 1999-07-20, CREATE BUY ORDER, 1.62
# 1999-07-21, BUY EXECUTED, Price: 1.60, Cost: 16.00, Comm 0.02
# 1999-07-21, Close, 1.57
# 1999-07-22, Close, 1.50
# 1999-07-23, Close, 1.50
# 1999-07-26, Close, 1.50
# 1999-07-27, Close, 1.51
# 1999-07-28, Close, 1.53
# 1999-07-28, CREATE SELl ORDER, 1.53
# 1999-07-29, SELL EXECUTED, Price: 1.50, Cost: 16.00, Comm 0.01
# 1999-07-29, OPERATION PROFIT, GROSS -1.00, NET -1.03
# 1999-07-29, Close, 1.55
# 1999-07-30, Close, 1.55
# 1999-08-02, Close, 1.57
# 1999-08-03, Close, 1.53
# 1999-08-04, Close, 1.53
# 1999-08-05, Close, 1.55
# 1999-08-06, Close, 1.55
# 1999-08-09, Close, 1.55
# 1999-08-10, Close, 1.58
# 1999-08-11, Close, 1.69
# 1999-08-12, Close, 1.77
# 1999-08-13, Close, 1.75
# 1999-08-16, Close, 1.68
# 1999-08-16, CREATE BUY ORDER, 1.68
# 1999-08-17, BUY EXECUTED, Price: 1.69, Cost: 16.90, Comm 0.02
# 1999-08-17, Close, 1.69
# 1999-08-18, Close, 1.73
# 1999-08-19, Close, 2.09
# 1999-08-20, Close, 2.07
# 1999-08-23, Close, 1.95
# 1999-08-24, Close, 1.94
# 1999-08-24, CREATE SELl ORDER, 1.94
# 1999-08-25, SELL EXECUTED, Price: 1.94, Cost: 16.90, Comm 0.02
# 1999-08-25, OPERATION PROFIT, GROSS 2.50, NET 2.46
# 1999-08-25, Close, 1.93
# 1999-08-25, CREATE BUY ORDER, 1.93
# 1999-08-26, BUY EXECUTED, Price: 1.93, Cost: 19.30, Comm 0.02
# 1999-08-26, Close, 1.90
# 1999-08-27, Close, 2.01
# 1999-08-30, Close, 2.00
# 1999-08-31, Close, 2.17
# 1999-09-01, Close, 2.07
# 1999-09-02, Close, 2.04
# 1999-09-02, CREATE SELl ORDER, 2.04
# 1999-09-03, SELL EXECUTED, Price: 2.08, Cost: 19.30, Comm 0.02
# 1999-09-03, OPERATION PROFIT, GROSS 1.50, NET 1.46
# 1999-09-03, Close, 2.06
# 1999-09-07, Close, 2.05
# 1999-09-08, Close, 2.04
# 1999-09-08, CREATE BUY ORDER, 2.04
# 1999-09-09, BUY EXECUTED, Price: 2.06, Cost: 20.60, Comm 0.02
# 1999-09-09, Close, 2.01
# 1999-09-10, Close, 2.04
# 1999-09-13, Close, 1.98
# 1999-09-14, Close, 1.92
# 1999-09-15, Close, 1.93
# 1999-09-16, Close, 1.88
# 1999-09-16, CREATE SELl ORDER, 1.88
# 1999-09-17, SELL EXECUTED, Price: 1.87, Cost: 20.60, Comm 0.02
# 1999-09-17, OPERATION PROFIT, GROSS -1.90, NET -1.94
# 1999-09-17, Close, 1.88
# 1999-09-20, Close, 1.81
# 1999-09-21, Close, 1.64
# 1999-09-21, CREATE BUY ORDER, 1.64
# 1999-09-22, BUY EXECUTED, Price: 1.64, Cost: 16.40, Comm 0.02
# 1999-09-22, Close, 1.68
# 1999-09-23, Close, 1.54
# 1999-09-24, Close, 1.40
# 1999-09-27, Close, 1.48
# 1999-09-28, Close, 1.62
# 1999-09-29, Close, 1.49
# 1999-09-29, CREATE SELl ORDER, 1.49
# 1999-09-30, SELL EXECUTED, Price: 1.54, Cost: 16.40, Comm 0.02
# 1999-09-30, OPERATION PROFIT, GROSS -1.00, NET -1.03
# 1999-09-30, Close, 1.48
# 1999-09-30, CREATE BUY ORDER, 1.48
# 1999-10-01, BUY EXECUTED, Price: 1.46, Cost: 14.60, Comm 0.01
# 1999-10-01, Close, 1.48
# 1999-10-04, Close, 1.50
# 1999-10-05, Close, 1.65
# 1999-10-06, Close, 1.85
# 1999-10-07, Close, 1.73
# 1999-10-08, Close, 1.81
# 1999-10-08, CREATE SELl ORDER, 1.81
# 1999-10-11, SELL EXECUTED, Price: 1.83, Cost: 14.60, Comm 0.02
# 1999-10-11, OPERATION PROFIT, GROSS 3.70, NET 3.67
# 1999-10-11, Close, 1.76
# 1999-10-12, Close, 1.74
# 1999-10-12, CREATE BUY ORDER, 1.74
# 1999-10-13, BUY EXECUTED, Price: 1.72, Cost: 17.20, Comm 0.02
# 1999-10-13, Close, 1.69
# 1999-10-14, Close, 1.66
# 1999-10-15, Close, 1.65
# 1999-10-18, Close, 1.56
# 1999-10-19, Close, 1.50
# 1999-10-20, Close, 1.55
# 1999-10-20, CREATE SELl ORDER, 1.55
# 1999-10-21, SELL EXECUTED, Price: 1.55, Cost: 17.20, Comm 0.02
# 1999-10-21, OPERATION PROFIT, GROSS -1.70, NET -1.73
# 1999-10-21, Close, 1.62
# 1999-10-22, Close, 1.66
# 1999-10-25, Close, 1.58
# 1999-10-26, Close, 1.74
# 1999-10-27, Close, 1.66
# 1999-10-28, Close, 1.58
# 1999-10-28, CREATE BUY ORDER, 1.58
# 1999-10-29, BUY EXECUTED, Price: 1.60, Cost: 16.00, Comm 0.02
# 1999-10-29, Close, 1.71
# 1999-11-01, Close, 1.81
# 1999-11-02, Close, 1.93
# 1999-11-03, Close, 2.12
# 1999-11-04, Close, 2.25
# 1999-11-05, Close, 2.18
# 1999-11-05, CREATE SELl ORDER, 2.18
# 1999-11-08, SELL EXECUTED, Price: 2.11, Cost: 16.00, Comm 0.02
# 1999-11-08, OPERATION PROFIT, GROSS 5.10, NET 5.06
# 1999-11-08, Close, 2.24
# 1999-11-09, Close, 2.21
# 1999-11-10, Close, 2.19
# 1999-11-10, CREATE BUY ORDER, 2.19
# 1999-11-11, BUY EXECUTED, Price: 2.19, Cost: 21.90, Comm 0.02
# 1999-11-11, Close, 2.34
# 1999-11-12, Close, 2.47
# 1999-11-15, Close, 2.42
# 1999-11-16, Close, 2.65
# 1999-11-17, Close, 2.75
# 1999-11-18, Close, 2.76
# 1999-11-18, CREATE SELl ORDER, 2.76
# 1999-11-19, SELL EXECUTED, Price: 3.09, Cost: 21.90, Comm 0.03
# 1999-11-19, OPERATION PROFIT, GROSS 9.00, NET 8.95
# 1999-11-19, Close, 3.31
# 1999-11-22, Close, 3.30
# 1999-11-23, Close, 3.07
# 1999-11-23, CREATE BUY ORDER, 3.07
# 1999-11-24, BUY EXECUTED, Price: 3.05, Cost: 30.50, Comm 0.03
# 1999-11-24, Close, 2.97
# 1999-11-26, Close, 2.95
# 1999-11-29, Close, 2.84
# 1999-11-30, Close, 2.67
# 1999-12-01, Close, 2.81
# 1999-12-02, Close, 3.01
# 1999-12-02, CREATE SELl ORDER, 3.01
# 1999-12-03, SELL EXECUTED, Price: 3.04, Cost: 30.50, Comm 0.03
# 1999-12-03, OPERATION PROFIT, GROSS -0.10, NET -0.16
# 1999-12-03, Close, 2.94
# 1999-12-06, Close, 3.02
# 1999-12-07, Close, 2.92
# 1999-12-08, Close, 3.05
# 1999-12-09, Close, 2.96
# 1999-12-10, Close, 2.93
# 1999-12-10, CREATE BUY ORDER, 2.93
# 1999-12-13, BUY EXECUTED, Price: 2.89, Cost: 28.90, Comm 0.03
# 1999-12-13, Close, 2.92
# 1999-12-14, Close, 2.87
# 1999-12-15, Close, 2.78
# 1999-12-16, Close, 2.76
# 1999-12-17, Close, 2.90
# 1999-12-20, Close, 3.14
# 1999-12-20, CREATE SELl ORDER, 3.14
# 1999-12-21, SELL EXECUTED, Price: 3.14, Cost: 28.90, Comm 0.03
# 1999-12-21, OPERATION PROFIT, GROSS 2.50, NET 2.44
# 1999-12-21, Close, 3.28
# 1999-12-22, Close, 3.35
# 1999-12-23, Close, 3.58
# 1999-12-27, Close, 3.44
# 1999-12-28, Close, 3.43
# 1999-12-28, CREATE BUY ORDER, 3.43
# 1999-12-29, BUY EXECUTED, Price: 3.42, Cost: 34.20, Comm 0.03
# 1999-12-29, Close, 3.55
# 1999-12-30, Close, 3.58
# 1999-12-31, Close, 3.62
# 2000-01-03, Close, 3.61
# 2000-01-04, Close, 3.51
# 2000-01-05, Close, 3.40
# 2000-01-05, CREATE SELl ORDER, 3.40
# 2000-01-06, SELL EXECUTED, Price: 3.40, Cost: 34.20, Comm 0.03
# 2000-01-06, OPERATION PROFIT, GROSS -0.20, NET -0.27
# 2000-01-06, Close, 3.18
# 2000-01-06, CREATE BUY ORDER, 3.18
# 2000-01-07, BUY EXECUTED, Price: 3.16, Cost: 31.60, Comm 0.03
# 2000-01-07, Close, 3.23
# 2000-01-10, Close, 3.34
# 2000-01-11, Close, 3.20
# 2000-01-12, Close, 3.12
# 2000-01-13, Close, 3.25
# 2000-01-14, Close, 3.39
# 2000-01-14, CREATE SELl ORDER, 3.39
# 2000-01-18, SELL EXECUTED, Price: 3.43, Cost: 31.60, Comm 0.03
# 2000-01-18, OPERATION PROFIT, GROSS 2.70, NET 2.63
# 2000-01-18, Close, 3.53
# 2000-01-19, Close, 3.50
# 2000-01-20, Close, 3.49
# 2000-01-20, CREATE BUY ORDER, 3.49
# 2000-01-21, BUY EXECUTED, Price: 3.48, Cost: 34.80, Comm 0.03
# 2000-01-21, Close, 3.45
# 2000-01-24, Close, 3.30
# 2000-01-25, Close, 3.27
# 2000-01-26, Close, 3.13
# 2000-01-27, Close, 2.97
# 2000-01-28, Close, 2.88
# 2000-01-28, CREATE SELl ORDER, 2.88
# 2000-01-31, SELL EXECUTED, Price: 2.90, Cost: 34.80, Comm 0.03
# 2000-01-31, OPERATION PROFIT, GROSS -5.80, NET -5.86
# 2000-01-31, Close, 2.86
# 2000-01-31, CREATE BUY ORDER, 2.86
# 2000-02-01, BUY EXECUTED, Price: 2.86, Cost: 28.60, Comm 0.03
# 2000-02-01, Close, 2.93
# 2000-02-02, Close, 3.01
# 2000-02-03, Close, 3.06
# 2000-02-04, Close, 3.13
# 2000-02-07, Close, 2.94
# 2000-02-08, Close, 3.08
# 2000-02-08, CREATE SELl ORDER, 3.08
# 2000-02-09, SELL EXECUTED, Price: 3.19, Cost: 28.60, Comm 0.03
# 2000-02-09, OPERATION PROFIT, GROSS 3.30, NET 3.24
# 2000-02-09, Close, 3.15
# 2000-02-10, Close, 3.80
# 2000-02-11, Close, 3.86
# 2000-02-14, Close, 4.47
# 2000-02-15, Close, 4.30
# 2000-02-16, Close, 4.50
# 2000-02-17, Close, 4.66
# 2000-02-18, Close, 5.20
# 2000-02-22, Close, 5.05
# 2000-02-23, Close, 5.08
# 2000-02-24, Close, 5.03
# 2000-02-25, Close, 4.72
# 2000-02-25, CREATE BUY ORDER, 4.72
# 2000-02-28, BUY EXECUTED, Price: 4.70, Cost: 47.00, Comm 0.05
# 2000-02-28, Close, 4.69
# 2000-02-29, Close, 4.94
# 2000-03-01, Close, 4.79
# 2000-03-02, Close, 4.47
# 2000-03-03, Close, 4.54
# 2000-03-06, Close, 4.51
# 2000-03-06, CREATE SELl ORDER, 4.51
# 2000-03-07, SELL EXECUTED, Price: 5.78, Cost: 47.00, Comm 0.06
# 2000-03-07, OPERATION PROFIT, GROSS 10.80, NET 10.70
# 2000-03-07, Close, 6.43
# 2000-03-08, Close, 6.48
# 2000-03-09, Close, 7.74
# 2000-03-10, Close, 9.10
# 2000-03-13, Close, 11.51
# 2000-03-14, Close, 8.49
# 2000-03-15, Close, 8.15
# 2000-03-15, CREATE BUY ORDER, 8.15
# 2000-03-16, BUY EXECUTED, Price: 8.41, Cost: 84.10, Comm 0.08
# 2000-03-16, Close, 7.26
# 2000-03-17, Close, 7.70
# 2000-03-20, Close, 7.70
# 2000-03-21, Close, 7.32
# 2000-03-22, Close, 7.37
# 2000-03-23, Close, 7.50
# 2000-03-23, CREATE SELl ORDER, 7.50
# 2000-03-24, SELL EXECUTED, Price: 7.45, Cost: 84.10, Comm 0.07
# 2000-03-24, OPERATION PROFIT, GROSS -9.60, NET -9.76
# 2000-03-24, Close, 7.19
# 2000-03-27, Close, 6.71
# 2000-03-27, CREATE BUY ORDER, 6.71
# 2000-03-28, BUY EXECUTED, Price: 6.48, Cost: 64.80, Comm 0.06
# 2000-03-28, Close, 6.21
# 2000-03-29, Close, 5.80
# 2000-03-30, Close, 5.77
# 2000-03-31, Close, 6.52
# 2000-04-03, Close, 6.01
# 2000-04-04, Close, 5.78
# 2000-04-04, CREATE SELl ORDER, 5.78
# 2000-04-05, SELL EXECUTED, Price: 5.84, Cost: 64.80, Comm 0.06
# 2000-04-05, OPERATION PROFIT, GROSS -6.40, NET -6.52
# 2000-04-05, Close, 7.07
# 2000-04-06, Close, 7.40
# 2000-04-07, Close, 7.91
# 2000-04-10, Close, 7.21
# 2000-04-11, Close, 6.78
# 2000-04-11, CREATE BUY ORDER, 6.78
# 2000-04-12, BUY EXECUTED, Price: 6.79, Cost: 67.90, Comm 0.07
# 2000-04-12, Close, 6.08
# 2000-04-13, Close, 5.82
# 2000-04-14, Close, 5.31
# 2000-04-17, Close, 5.58
# 2000-04-18, Close, 6.57
# 2000-04-19, Close, 6.25
# 2000-04-19, CREATE SELl ORDER, 6.25
# 2000-04-20, SELL EXECUTED, Price: 6.42, Cost: 67.90, Comm 0.06
# 2000-04-20, OPERATION PROFIT, GROSS -3.70, NET -3.83
# 2000-04-20, Close, 6.22
# 2000-04-20, CREATE BUY ORDER, 6.22
# 2000-04-24, BUY EXECUTED, Price: 5.86, Cost: 58.60, Comm 0.06
# 2000-04-24, Close, 5.91
# 2000-04-25, Close, 6.56
# 2000-04-26, Close, 6.49
# 2000-04-27, Close, 7.02
# 2000-04-28, Close, 6.87
# 2000-05-01, Close, 7.10
# 2000-05-01, CREATE SELl ORDER, 7.10
# 2000-05-02, SELL EXECUTED, Price: 7.10, Cost: 58.60, Comm 0.07
# 2000-05-02, OPERATION PROFIT, GROSS 12.40, NET 12.27
# 2000-05-02, Close, 6.82
# 2000-05-03, Close, 6.71
# 2000-05-03, CREATE BUY ORDER, 6.71
# 2000-05-04, BUY EXECUTED, Price: 6.70, Cost: 67.00, Comm 0.07
# 2000-05-04, Close, 6.79
# 2000-05-05, Close, 7.11
# 2000-05-08, Close, 6.84
# 2000-05-09, Close, 6.75
# 2000-05-10, Close, 6.08
# 2000-05-11, Close, 6.34
# 2000-05-11, CREATE SELl ORDER, 6.34
# 2000-05-12, SELL EXECUTED, Price: 6.52, Cost: 67.00, Comm 0.07
# 2000-05-12, OPERATION PROFIT, GROSS -1.80, NET -1.93
# 2000-05-12, Close, 6.15
# 2000-05-15, Close, 6.58
# 2000-05-16, Close, 7.25
# 2000-05-17, Close, 8.52
# 2000-05-18, Close, 7.94
# 2000-05-19, Close, 7.88
# 2000-05-19, CREATE BUY ORDER, 7.88
# 2000-05-22, BUY EXECUTED, Price: 7.79, Cost: 77.90, Comm 0.08
# 2000-05-22, Close, 8.39
# 2000-05-23, Close, 8.32
# 2000-05-24, Close, 8.21
# 2000-05-25, Close, 8.10
# 2000-05-26, Close, 8.14
# 2000-05-30, Close, 8.47
# 2000-05-30, CREATE SELl ORDER, 8.47
# 2000-05-31, SELL EXECUTED, Price: 8.45, Cost: 77.90, Comm 0.08
# 2000-05-31, OPERATION PROFIT, GROSS 6.60, NET 6.44
# 2000-05-31, Close, 8.80
# 2000-06-01, Close, 9.05
# 2000-06-02, Close, 10.15
# 2000-06-05, Close, 10.37
# 2000-06-06, Close, 9.85
# 2000-06-07, Close, 9.41
# 2000-06-07, CREATE BUY ORDER, 9.41
# 2000-06-08, BUY EXECUTED, Price: 9.65, Cost: 96.50, Comm 0.10
# 2000-06-08, Close, 9.48
# 2000-06-09, Close, 9.75
# 2000-06-12, Close, 9.49
# 2000-06-13, Close, 9.79
# 2000-06-14, Close, 9.78
# 2000-06-15, Close, 10.04
# 2000-06-15, CREATE SELl ORDER, 10.04
# 2000-06-16, SELL EXECUTED, Price: 10.00, Cost: 96.50, Comm 0.10
# 2000-06-16, OPERATION PROFIT, GROSS 3.50, NET 3.30
# 2000-06-16, Close, 11.55
# 2000-06-19, Close, 12.27
# 2000-06-20, Close, 12.11
# 2000-06-21, Close, 13.34
# 2000-06-22, Close, 12.61
# 2000-06-23, Close, 11.42
# 2000-06-23, CREATE BUY ORDER, 11.42
# 2000-06-26, BUY EXECUTED, Price: 11.65, Cost: 116.50, Comm 0.12
# 2000-06-26, Close, 12.80
# 2000-06-27, Close, 10.99
# 2000-06-28, Close, 10.57
# 2000-06-29, Close, 9.04
# 2000-06-30, Close, 9.80
# 2000-07-03, Close, 9.43
# 2000-07-03, CREATE SELl ORDER, 9.43
# 2000-07-05, SELL EXECUTED, Price: 9.39, Cost: 116.50, Comm 0.09
# 2000-07-05, OPERATION PROFIT, GROSS -22.60, NET -22.81
# 2000-07-05, Close, 8.42
# 2000-07-05, CREATE BUY ORDER, 8.42
# 2000-07-06, BUY EXECUTED, Price: 8.43, Cost: 84.30, Comm 0.08
# 2000-07-06, Close, 8.93
# 2000-07-07, Close, 8.98
# 2000-07-10, Close, 9.44
# 2000-07-11, Close, 10.20
# 2000-07-12, Close, 10.49
# 2000-07-13, Close, 11.47
# 2000-07-13, CREATE SELl ORDER, 11.47
# 2000-07-14, SELL EXECUTED, Price: 11.70, Cost: 84.30, Comm 0.12
# 2000-07-14, OPERATION PROFIT, GROSS 32.70, NET 32.50
# 2000-07-14, Close, 11.39
# 2000-07-17, Close, 11.26
# 2000-07-17, CREATE BUY ORDER, 11.26
# 2000-07-18, BUY EXECUTED, Price: 10.64, Cost: 106.40, Comm 0.11
# 2000-07-18, Close, 11.04
# 2000-07-19, Close, 10.33
# 2000-07-20, Close, 10.61
# 2000-07-21, Close, 10.75
# 2000-07-24, Close, 9.83
# 2000-07-25, Close, 9.47
# 2000-07-25, CREATE SELl ORDER, 9.47
# 2000-07-26, SELL EXECUTED, Price: 9.47, Cost: 106.40, Comm 0.09
# 2000-07-26, OPERATION PROFIT, GROSS -11.70, NET -11.90
# 2000-07-26, Close, 8.76
# 2000-07-26, CREATE BUY ORDER, 8.76
# 2000-07-27, BUY EXECUTED, Price: 8.48, Cost: 84.80, Comm 0.08
# 2000-07-27, Close, 8.14
# 2000-07-28, Close, 8.33
# 2000-07-31, Close, 9.26
# 2000-08-01, Close, 9.07
# 2000-08-02, Close, 9.26
# 2000-08-03, Close, 9.66
# 2000-08-03, CREATE SELl ORDER, 9.66
# 2000-08-04, SELL EXECUTED, Price: 9.89, Cost: 84.80, Comm 0.10
# 2000-08-04, OPERATION PROFIT, GROSS 14.10, NET 13.92
# 2000-08-04, Close, 9.83
# 2000-08-07, Close, 10.60
# 2000-08-08, Close, 10.37
# 2000-08-09, Close, 10.06
# 2000-08-09, CREATE BUY ORDER, 10.06
# 2000-08-10, BUY EXECUTED, Price: 9.83, Cost: 98.30, Comm 0.10
# 2000-08-10, Close, 10.18
# 2000-08-11, Close, 9.94
# 2000-08-14, Close, 10.04
# 2000-08-15, Close, 10.98
# 2000-08-16, Close, 11.26
# 2000-08-17, Close, 11.47
# 2000-08-17, CREATE SELl ORDER, 11.47
# 2000-08-18, SELL EXECUTED, Price: 11.42, Cost: 98.30, Comm 0.11
# 2000-08-18, OPERATION PROFIT, GROSS 15.90, NET 15.69
# 2000-08-18, Close, 11.88
# 2000-08-21, Close, 12.06
# 2000-08-22, Close, 10.92
# 2000-08-23, Close, 11.56
# 2000-08-24, Close, 11.87
# 2000-08-25, Close, 11.57
# 2000-08-28, Close, 12.03
# 2000-08-29, Close, 12.00
# 2000-08-30, Close, 12.11
# 2000-08-31, Close, 12.24
# 2000-09-01, Close, 12.26
# 2000-09-05, Close, 12.28
# 2000-09-06, Close, 11.43
# 2000-09-07, Close, 12.05
# 2000-09-08, Close, 11.34
# 2000-09-11, Close, 10.87
# 2000-09-11, CREATE BUY ORDER, 10.87
# 2000-09-12, BUY EXECUTED, Price: 10.88, Cost: 108.80, Comm 0.11
# 2000-09-12, Close, 10.81
# 2000-09-13, Close, 10.80
# 2000-09-14, Close, 10.70
# 2000-09-15, Close, 10.94
# 2000-09-18, Close, 10.30
# 2000-09-19, Close, 10.61
# 2000-09-19, CREATE SELl ORDER, 10.61
# 2000-09-20, SELL EXECUTED, Price: 10.33, Cost: 108.80, Comm 0.10
# 2000-09-20, OPERATION PROFIT, GROSS -5.50, NET -5.71
# 2000-09-20, Close, 10.27
# 2000-09-21, Close, 10.71
# 2000-09-22, Close, 10.89
# 2000-09-25, Close, 11.67
# 2000-09-26, Close, 11.95
# 2000-09-27, Close, 12.61
# 2000-09-28, Close, 13.00
# 2000-09-29, Close, 12.63
# 2000-10-02, Close, 12.33
# 2000-10-02, CREATE BUY ORDER, 12.33
# 2000-10-03, BUY EXECUTED, Price: 12.40, Cost: 124.00, Comm 0.12
# 2000-10-03, Close, 11.67
# 2000-10-04, Close, 11.53
# 2000-10-05, Close, 11.26
# 2000-10-06, Close, 10.56
# 2000-10-09, Close, 10.79
# 2000-10-10, Close, 9.97
# 2000-10-10, CREATE SELl ORDER, 9.97
# 2000-10-11, SELL EXECUTED, Price: 9.36, Cost: 124.00, Comm 0.09
# 2000-10-11, OPERATION PROFIT, GROSS -30.40, NET -30.62
# 2000-10-11, Close, 10.06
# 2000-10-12, Close, 9.66
# 2000-10-13, Close, 10.05
# 2000-10-16, Close, 9.81
# 2000-10-17, Close, 9.10
# 2000-10-17, CREATE BUY ORDER, 9.10
# 2000-10-18, BUY EXECUTED, Price: 8.51, Cost: 85.10, Comm 0.09
# 2000-10-18, Close, 8.96
# 2000-10-19, Close, 9.82
# 2000-10-20, Close, 10.74
# 2000-10-23, Close, 10.50
# 2000-10-24, Close, 10.16
# 2000-10-25, Close, 9.27
# 2000-10-25, CREATE SELl ORDER, 9.27
# 2000-10-26, SELL EXECUTED, Price: 9.33, Cost: 85.10, Comm 0.09
# 2000-10-26, OPERATION PROFIT, GROSS 8.20, NET 8.02
# 2000-10-26, Close, 9.67
# 2000-10-27, Close, 9.45
# 2000-10-30, Close, 8.78
# 2000-10-30, CREATE BUY ORDER, 8.78
# 2000-10-31, BUY EXECUTED, Price: 9.13, Cost: 91.30, Comm 0.09
# 2000-10-31, Close, 9.59
# 2000-11-01, Close, 9.58
# 2000-11-02, Close, 10.32
# 2000-11-03, Close, 10.99
# 2000-11-06, Close, 11.84
# 2000-11-07, Close, 11.04
# 2000-11-07, CREATE SELl ORDER, 11.04
# 2000-11-08, SELL EXECUTED, Price: 11.16, Cost: 91.30, Comm 0.11
# 2000-11-08, OPERATION PROFIT, GROSS 20.30, NET 20.10
# 2000-11-08, Close, 10.71
# 2000-11-08, CREATE BUY ORDER, 10.71
# 2000-11-09, BUY EXECUTED, Price: 10.06, Cost: 100.60, Comm 0.10
# 2000-11-09, Close, 9.59
# 2000-11-10, Close, 9.07
# 2000-11-13, Close, 9.11
# 2000-11-14, Close, 10.78
# 2000-11-15, Close, 10.64
# 2000-11-16, Close, 9.97
# 2000-11-16, CREATE SELl ORDER, 9.97
# 2000-11-17, SELL EXECUTED, Price: 10.05, Cost: 100.60, Comm 0.10
# 2000-11-17, OPERATION PROFIT, GROSS -0.10, NET -0.30
# 2000-11-17, Close, 9.78
# 2000-11-17, CREATE BUY ORDER, 9.78
# 2000-11-20, BUY EXECUTED, Price: 9.41, Cost: 94.10, Comm 0.09
# 2000-11-20, Close, 9.02
# 2000-11-21, Close, 8.85
# 2000-11-22, Close, 8.39
# 2000-11-24, Close, 8.87
# 2000-11-27, Close, 8.57
# 2000-11-28, Close, 7.93
# 2000-11-28, CREATE SELl ORDER, 7.93
# 2000-11-29, SELL EXECUTED, Price: 8.05, Cost: 94.10, Comm 0.08
# 2000-11-29, OPERATION PROFIT, GROSS -13.60, NET -13.77
# 2000-11-29, Close, 7.44
# 2000-11-29, CREATE BUY ORDER, 7.44
# 2000-11-30, BUY EXECUTED, Price: 6.81, Cost: 68.10, Comm 0.07
# 2000-11-30, Close, 6.25
# 2000-12-01, Close, 6.86
# 2000-12-04, Close, 6.97
# 2000-12-05, Close, 7.42
# 2000-12-06, Close, 6.36
# 2000-12-07, Close, 6.25
# 2000-12-07, CREATE SELl ORDER, 6.25
# 2000-12-08, SELL EXECUTED, Price: 6.89, Cost: 68.10, Comm 0.07
# 2000-12-08, OPERATION PROFIT, GROSS 0.80, NET 0.66
# 2000-12-08, Close, 7.67
# 2000-12-11, Close, 7.67
# 2000-12-12, Close, 7.46
# 2000-12-13, Close, 6.88
# 2000-12-13, CREATE BUY ORDER, 6.88
# 2000-12-14, BUY EXECUTED, Price: 6.84, Cost: 68.40, Comm 0.07
# 2000-12-14, Close, 6.41
# 2000-12-15, Close, 5.77
# 2000-12-18, Close, 5.97
# 2000-12-19, Close, 5.51
# 2000-12-20, Close, 4.92
# 2000-12-21, Close, 4.30
# 2000-12-21, CREATE SELl ORDER, 4.30
# 2000-12-22, SELL EXECUTED, Price: 4.65, Cost: 68.40, Comm 0.05
# 2000-12-22, OPERATION PROFIT, GROSS -21.90, NET -22.01
# 2000-12-22, Close, 5.41
# 2000-12-26, Close, 5.19
# 2000-12-27, Close, 5.53
# 2000-12-28, Close, 5.56
# 2000-12-29, Close, 5.05
# 2001-01-02, Close, 4.62
# 2001-01-02, CREATE BUY ORDER, 4.62
# 2001-01-03, BUY EXECUTED, Price: 4.47, Cost: 44.70, Comm 0.04
# 2001-01-03, Close, 6.04
# 2001-01-04, Close, 6.73
# 2001-01-05, Close, 5.72
# 2001-01-08, Close, 6.27
# 2001-01-09, Close, 6.39
# 2001-01-10, Close, 6.84
# 2001-01-10, CREATE SELl ORDER, 6.84
# 2001-01-11, SELL EXECUTED, Price: 6.67, Cost: 44.70, Comm 0.07
# 2001-01-11, OPERATION PROFIT, GROSS 22.00, NET 21.89
# 2001-01-11, Close, 7.40
# 2001-01-12, Close, 7.25
# 2001-01-16, Close, 6.68
# 2001-01-16, CREATE BUY ORDER, 6.68
# 2001-01-17, BUY EXECUTED, Price: 7.19, Cost: 71.90, Comm 0.07
# 2001-01-17, Close, 6.92
# 2001-01-18, Close, 8.25
# 2001-01-19, Close, 8.03
# 2001-01-22, Close, 7.71
# 2001-01-23, Close, 8.48
# 2001-01-24, Close, 8.45
# 2001-01-24, CREATE SELl ORDER, 8.45
# 2001-01-25, SELL EXECUTED, Price: 8.16, Cost: 71.90, Comm 0.08
# 2001-01-25, OPERATION PROFIT, GROSS 9.70, NET 9.55
# 2001-01-25, Close, 7.60
# 2001-01-25, CREATE BUY ORDER, 7.60
# 2001-01-26, BUY EXECUTED, Price: 7.17, Cost: 71.70, Comm 0.07
# 2001-01-26, Close, 7.84
# 2001-01-29, Close, 7.88
# 2001-01-30, Close, 8.05
# 2001-01-31, Close, 7.96
# 2001-02-01, Close, 8.00
# 2001-02-02, Close, 7.23
# 2001-02-02, CREATE SELl ORDER, 7.23
# 2001-02-05, SELL EXECUTED, Price: 7.22, Cost: 71.70, Comm 0.07
# 2001-02-05, OPERATION PROFIT, GROSS 0.50, NET 0.36
# 2001-02-05, Close, 7.22
# 2001-02-05, CREATE BUY ORDER, 7.22
# 2001-02-06, BUY EXECUTED, Price: 7.09, Cost: 70.90, Comm 0.07
# 2001-02-06, Close, 7.26
# 2001-02-07, Close, 6.92
# 2001-02-08, Close, 6.88
# 2001-02-09, Close, 6.84
# 2001-02-12, Close, 6.65
# 2001-02-13, Close, 6.85
# 2001-02-13, CREATE SELl ORDER, 6.85
# 2001-02-14, SELL EXECUTED, Price: 6.77, Cost: 70.90, Comm 0.07
# 2001-02-14, OPERATION PROFIT, GROSS -3.20, NET -3.34
# 2001-02-14, Close, 7.36
# 2001-02-15, Close, 8.71
# 2001-02-16, Close, 9.18
# 2001-02-20, Close, 8.26
# 2001-02-21, Close, 8.64
# 2001-02-22, Close, 9.00
# 2001-02-23, Close, 8.38
# 2001-02-26, Close, 8.19
# 2001-02-26, CREATE BUY ORDER, 8.19
# 2001-02-27, BUY EXECUTED, Price: 7.99, Cost: 79.90, Comm 0.08
# 2001-02-27, Close, 7.70
# 2001-02-28, Close, 6.89
# 2001-03-01, Close, 7.44
# 2001-03-02, Close, 6.72
# 2001-03-05, Close, 6.79
# 2001-03-06, Close, 7.44
# 2001-03-06, CREATE SELl ORDER, 7.44
# 2001-03-07, SELL EXECUTED, Price: 7.61, Cost: 79.90, Comm 0.08
# 2001-03-07, OPERATION PROFIT, GROSS -3.80, NET -3.96
# 2001-03-07, Close, 8.04
# 2001-03-08, Close, 8.31
# 2001-03-09, Close, 7.72
# 2001-03-12, Close, 7.44
# 2001-03-12, CREATE BUY ORDER, 7.44
# 2001-03-13, BUY EXECUTED, Price: 7.54, Cost: 75.40, Comm 0.08
# 2001-03-13, Close, 8.33
# 2001-03-14, Close, 8.80
# 2001-03-15, Close, 9.24
# 2001-03-16, Close, 9.20
# 2001-03-19, Close, 9.73
# 2001-03-20, Close, 8.82
# 2001-03-20, CREATE SELl ORDER, 8.82
# 2001-03-21, SELL EXECUTED, Price: 8.84, Cost: 75.40, Comm 0.09
# 2001-03-21, OPERATION PROFIT, GROSS 13.00, NET 12.84
# 2001-03-21, Close, 9.48
# 2001-03-22, Close, 10.43
# 2001-03-23, Close, 10.33
# 2001-03-26, Close, 10.89
# 2001-03-27, Close, 10.50
# 2001-03-28, Close, 10.51
# 2001-03-29, Close, 10.66
# 2001-03-30, Close, 10.01
# 2001-04-02, Close, 9.59
# 2001-04-02, CREATE BUY ORDER, 9.59
# 2001-04-03, BUY EXECUTED, Price: 9.45, Cost: 94.50, Comm 0.09
# 2001-04-03, Close, 9.91
# 2001-04-04, Close, 8.89
# 2001-04-05, Close, 9.71
# 2001-04-06, Close, 9.67
# 2001-04-09, Close, 9.20
# 2001-04-10, Close, 10.07
# 2001-04-10, CREATE SELl ORDER, 10.07
# 2001-04-11, SELL EXECUTED, Price: 10.69, Cost: 94.50, Comm 0.11
# 2001-04-11, OPERATION PROFIT, GROSS 12.40, NET 12.20
# 2001-04-11, Close, 10.68
# 2001-04-12, Close, 10.84
# 2001-04-16, Close, 10.57
# 2001-04-17, Close, 11.09
# 2001-04-18, Close, 11.92
# 2001-04-19, Close, 12.94
# 2001-04-20, Close, 13.41
# 2001-04-23, Close, 12.71
# 2001-04-24, Close, 11.81
# 2001-04-24, CREATE BUY ORDER, 11.81
# 2001-04-25, BUY EXECUTED, Price: 11.84, Cost: 118.40, Comm 0.12
# 2001-04-25, Close, 12.35
# 2001-04-26, Close, 11.38
# 2001-04-27, Close, 12.19
# 2001-04-30, Close, 12.85
# 2001-05-01, Close, 14.05
# 2001-05-02, Close, 13.73
# 2001-05-02, CREATE SELl ORDER, 13.73
# 2001-05-03, SELL EXECUTED, Price: 13.31, Cost: 118.40, Comm 0.13
# 2001-05-03, OPERATION PROFIT, GROSS 14.70, NET 14.45
# 2001-05-03, Close, 13.67
# 2001-05-03, CREATE BUY ORDER, 13.67
# 2001-05-04, BUY EXECUTED, Price: 13.27, Cost: 132.70, Comm 0.13
# 2001-05-04, Close, 13.85
# 2001-05-07, Close, 14.48
# 2001-05-08, Close, 13.43
# 2001-05-09, Close, 12.80
# 2001-05-10, Close, 12.37
# 2001-05-11, Close, 12.05
# 2001-05-11, CREATE SELl ORDER, 12.05
# 2001-05-14, SELL EXECUTED, Price: 12.09, Cost: 132.70, Comm 0.12
# 2001-05-14, OPERATION PROFIT, GROSS -11.80, NET -12.05
# 2001-05-14, Close, 12.16
# 2001-05-15, Close, 12.59
# 2001-05-16, Close, 13.19
# 2001-05-17, Close, 13.42
# 2001-05-18, Close, 13.31
# 2001-05-21, Close, 13.91
# 2001-05-22, Close, 14.33
# 2001-05-23, Close, 14.21
# 2001-05-24, Close, 14.42
# 2001-05-25, Close, 14.14
# 2001-05-29, Close, 13.56
# 2001-05-29, CREATE BUY ORDER, 13.56
# 2001-05-30, BUY EXECUTED, Price: 13.25, Cost: 132.50, Comm 0.13
# 2001-05-30, Close, 13.31
# 2001-05-31, Close, 13.21
# 2001-06-01, Close, 13.94
# 2001-06-04, Close, 13.72
# 2001-06-05, Close, 14.44
# 2001-06-06, Close, 14.50
# 2001-06-06, CREATE SELl ORDER, 14.50
# 2001-06-07, SELL EXECUTED, Price: 14.37, Cost: 132.50, Comm 0.14
# 2001-06-07, OPERATION PROFIT, GROSS 11.20, NET 10.92
# 2001-06-07, Close, 15.32
# 2001-06-08, Close, 14.92
# 2001-06-11, Close, 14.49
# 2001-06-11, CREATE BUY ORDER, 14.49
# 2001-06-12, BUY EXECUTED, Price: 14.18, Cost: 141.80, Comm 0.14
# 2001-06-12, Close, 14.97
# 2001-06-13, Close, 14.47
# 2001-06-14, Close, 14.44
# 2001-06-15, Close, 14.66
# 2001-06-18, Close, 14.08
# 2001-06-19, Close, 13.31
# 2001-06-19, CREATE SELl ORDER, 13.31
# 2001-06-20, SELL EXECUTED, Price: 13.07, Cost: 141.80, Comm 0.13
# 2001-06-20, OPERATION PROFIT, GROSS -11.10, NET -11.37
# 2001-06-20, Close, 13.88
# 2001-06-21, Close, 14.15
# 2001-06-22, Close, 14.08
# 2001-06-25, Close, 14.06
# 2001-06-25, CREATE BUY ORDER, 14.06
# 2001-06-26, BUY EXECUTED, Price: 13.74, Cost: 137.40, Comm 0.14
# 2001-06-26, Close, 14.46
# 2001-06-27, Close, 14.01
# 2001-06-28, Close, 14.18
# 2001-06-29, Close, 14.31
# 2001-07-02, Close, 13.67
# 2001-07-03, Close, 13.85
# 2001-07-03, CREATE SELl ORDER, 13.85
# 2001-07-05, SELL EXECUTED, Price: 13.68, Cost: 137.40, Comm 0.14
# 2001-07-05, OPERATION PROFIT, GROSS -0.60, NET -0.87
# 2001-07-05, Close, 12.84
# 2001-07-06, Close, 12.45
# 2001-07-06, CREATE BUY ORDER, 12.45
# 2001-07-09, BUY EXECUTED, Price: 12.29, Cost: 122.90, Comm 0.12
# 2001-07-09, Close, 12.04
# 2001-07-10, Close, 12.14
# 2001-07-11, Close, 12.12
# 2001-07-12, Close, 12.75
# 2001-07-13, Close, 12.49
# 2001-07-16, Close, 11.48
# 2001-07-16, CREATE SELl ORDER, 11.48
# 2001-07-17, SELL EXECUTED, Price: 11.29, Cost: 122.90, Comm 0.11
# 2001-07-17, OPERATION PROFIT, GROSS -10.00, NET -10.24
# 2001-07-17, Close, 12.13
# 2001-07-18, Close, 11.71
# 2001-07-19, Close, 11.89
# 2001-07-20, Close, 11.55
# 2001-07-23, Close, 10.46
# 2001-07-23, CREATE BUY ORDER, 10.46
# 2001-07-24, BUY EXECUTED, Price: 10.60, Cost: 106.00, Comm 0.11
# 2001-07-24, Close, 11.17
# 2001-07-25, Close, 11.06
# 2001-07-26, Close, 12.19
# 2001-07-27, Close, 12.49
# 2001-07-30, Close, 12.20
# 2001-07-31, Close, 12.48
# 2001-07-31, CREATE SELl ORDER, 12.48
# 2001-08-01, SELL EXECUTED, Price: 12.72, Cost: 106.00, Comm 0.13
# 2001-08-01, OPERATION PROFIT, GROSS 21.20, NET 20.97
# 2001-08-01, Close, 13.24
# 2001-08-02, Close, 13.56
# 2001-08-03, Close, 13.45
# 2001-08-06, Close, 13.86
# 2001-08-07, Close, 13.65
# 2001-08-08, Close, 13.30
# 2001-08-08, CREATE BUY ORDER, 13.30
# 2001-08-09, BUY EXECUTED, Price: 13.24, Cost: 132.40, Comm 0.13
# 2001-08-09, Close, 13.07
# 2001-08-10, Close, 13.06
# 2001-08-13, Close, 13.60
# 2001-08-14, Close, 13.24
# 2001-08-15, Close, 13.26
# 2001-08-16, Close, 13.82
# 2001-08-16, CREATE SELl ORDER, 13.82
# 2001-08-17, SELL EXECUTED, Price: 13.47, Cost: 132.40, Comm 0.13
# 2001-08-17, OPERATION PROFIT, GROSS 2.30, NET 2.03
# 2001-08-17, Close, 12.92
# 2001-08-20, Close, 12.83
# 2001-08-20, CREATE BUY ORDER, 12.83
# 2001-08-21, BUY EXECUTED, Price: 12.86, Cost: 128.60, Comm 0.13
# 2001-08-21, Close, 12.56
# 2001-08-22, Close, 13.08
# 2001-08-23, Close, 12.79
# 2001-08-24, Close, 13.15
# 2001-08-27, Close, 13.61
# 2001-08-28, Close, 13.43
# 2001-08-28, CREATE SELl ORDER, 13.43
# 2001-08-29, SELL EXECUTED, Price: 13.47, Cost: 128.60, Comm 0.13
# 2001-08-29, OPERATION PROFIT, GROSS 6.10, NET 5.84
# 2001-08-29, Close, 13.00
# 2001-08-29, CREATE BUY ORDER, 13.00
# 2001-08-30, BUY EXECUTED, Price: 12.76, Cost: 127.60, Comm 0.13
# 2001-08-30, Close, 12.96
# 2001-08-31, Close, 13.07
# 2001-09-04, Close, 12.16
# 2001-09-05, Close, 12.42
# 2001-09-06, Close, 11.91
# 2001-09-07, Close, 12.03
# 2001-09-07, CREATE SELl ORDER, 12.03
# 2001-09-10, SELL EXECUTED, Price: 11.93, Cost: 127.60, Comm 0.12
# 2001-09-10, OPERATION PROFIT, GROSS -8.30, NET -8.55
# 2001-09-10, Close, 11.69
# 2001-09-17, Close, 10.49
# 2001-09-17, CREATE BUY ORDER, 10.49
# 2001-09-18, BUY EXECUTED, Price: 10.69, Cost: 106.90, Comm 0.11
# 2001-09-18, Close, 9.85
# 2001-09-19, Close, 9.73
# 2001-09-20, Close, 8.91
# 2001-09-21, Close, 8.32
# 2001-09-24, Close, 9.26
# 2001-09-25, Close, 8.89
# 2001-09-25, CREATE SELl ORDER, 8.89
# 2001-09-26, SELL EXECUTED, Price: 9.01, Cost: 106.90, Comm 0.09
# 2001-09-26, OPERATION PROFIT, GROSS -16.80, NET -17.00
# 2001-09-26, Close, 8.57
# 2001-09-26, CREATE BUY ORDER, 8.57
# 2001-09-27, BUY EXECUTED, Price: 8.54, Cost: 85.40, Comm 0.09
# 2001-09-27, Close, 8.10
# 2001-09-28, Close, 8.47
# 2001-10-01, Close, 7.76
# 2001-10-02, Close, 7.37
# 2001-10-03, Close, 8.82
# 2001-10-04, Close, 9.96
# 2001-10-04, CREATE SELl ORDER, 9.96
# 2001-10-05, SELL EXECUTED, Price: 9.81, Cost: 85.40, Comm 0.10
# 2001-10-05, OPERATION PROFIT, GROSS 12.70, NET 12.52
# 2001-10-05, Close, 10.15
# 2001-10-08, Close, 10.38
# 2001-10-09, Close, 9.93
# 2001-10-10, Close, 10.57
# 2001-10-11, Close, 11.71
# 2001-10-12, Close, 12.47
# 2001-10-15, Close, 12.42
# 2001-10-16, Close, 13.67
# 2001-10-17, Close, 12.86
# 2001-10-18, Close, 13.41
# 2001-10-19, Close, 13.69
# 2001-10-22, Close, 14.01
# 2001-10-23, Close, 13.76
# 2001-10-24, Close, 14.37
# 2001-10-25, Close, 15.21
# 2001-10-26, Close, 14.13
# 2001-10-29, Close, 12.98
# 2001-10-29, CREATE BUY ORDER, 12.98
# 2001-10-30, BUY EXECUTED, Price: 12.74, Cost: 127.40, Comm 0.13
# 2001-10-30, Close, 12.96
# 2001-10-31, Close, 13.22
# 2001-11-01, Close, 14.35
# 2001-11-02, Close, 14.55
# 2001-11-05, Close, 14.60
# 2001-11-06, Close, 15.61
# 2001-11-06, CREATE SELl ORDER, 15.61
# 2001-11-07, SELL EXECUTED, Price: 15.49, Cost: 127.40, Comm 0.15
# 2001-11-07, OPERATION PROFIT, GROSS 27.50, NET 27.22
# 2001-11-07, Close, 15.62
# 2001-11-08, Close, 15.35
# 2001-11-09, Close, 16.41
# 2001-11-12, Close, 16.85
# 2001-11-13, Close, 16.71
# 2001-11-14, Close, 16.25
# 2001-11-14, CREATE BUY ORDER, 16.25
# 2001-11-15, BUY EXECUTED, Price: 16.06, Cost: 160.60, Comm 0.16
# 2001-11-15, Close, 16.34
# 2001-11-16, Close, 16.19
# 2001-11-19, Close, 15.84
# 2001-11-20, Close, 15.39
# 2001-11-21, Close, 15.20
# 2001-11-23, Close, 15.41
# 2001-11-23, CREATE SELl ORDER, 15.41
# 2001-11-26, SELL EXECUTED, Price: 15.67, Cost: 160.60, Comm 0.16
# 2001-11-26, OPERATION PROFIT, GROSS -3.90, NET -4.22
# 2001-11-26, Close, 16.51
# 2001-11-27, Close, 16.69
# 2001-11-28, Close, 15.84
# 2001-11-29, Close, 16.54
# 2001-11-30, Close, 16.86
# 2001-12-03, Close, 16.60
# 2001-12-04, Close, 17.94
# 2001-12-05, Close, 19.38
# 2001-12-06, Close, 19.08
# 2001-12-07, Close, 18.49
# 2001-12-07, CREATE BUY ORDER, 18.49
# 2001-12-10, BUY EXECUTED, Price: 18.40, Cost: 184.00, Comm 0.18
# 2001-12-10, Close, 18.68
# 2001-12-11, Close, 19.35
# 2001-12-12, Close, 19.95
# 2001-12-13, Close, 19.38
# 2001-12-14, Close, 20.25
# 2001-12-17, Close, 20.98
# 2001-12-17, CREATE SELl ORDER, 20.98
# 2001-12-18, SELL EXECUTED, Price: 20.52, Cost: 184.00, Comm 0.21
# 2001-12-18, OPERATION PROFIT, GROSS 21.20, NET 20.81
# 2001-12-18, Close, 20.44
# 2001-12-19, Close, 19.88
# 2001-12-19, CREATE BUY ORDER, 19.88
# 2001-12-20, BUY EXECUTED, Price: 19.96, Cost: 199.60, Comm 0.20
# 2001-12-20, Close, 19.10
# 2001-12-21, Close, 19.92
# 2001-12-24, Close, 20.42
# 2001-12-26, Close, 20.92
# 2001-12-27, Close, 21.40
# 2001-12-28, Close, 20.89
# 2001-12-28, CREATE SELl ORDER, 20.89
# 2001-12-31, SELL EXECUTED, Price: 21.04, Cost: 199.60, Comm 0.21
# 2001-12-31, OPERATION PROFIT, GROSS 10.80, NET 10.39
# 2001-12-31, Close, 20.64
# 2001-12-31, CREATE BUY ORDER, 20.64
# 2002-01-02, BUY EXECUTED, Price: 20.73, Cost: 207.30, Comm 0.21
# 2002-01-02, Close, 20.76
# 2002-01-03, Close, 22.12
# 2002-01-04, Close, 21.48
# 2002-01-07, Close, 20.90
# 2002-01-08, Close, 21.15
# 2002-01-09, Close, 20.86
# 2002-01-09, CREATE SELl ORDER, 20.86
# 2002-01-10, SELL EXECUTED, Price: 20.75, Cost: 207.30, Comm 0.21
# 2002-01-10, OPERATION PROFIT, GROSS 0.20, NET -0.21
# 2002-01-10, Close, 20.36
# 2002-01-10, CREATE BUY ORDER, 20.36
# 2002-01-11, BUY EXECUTED, Price: 20.49, Cost: 204.90, Comm 0.20
# 2002-01-11, Close, 19.46
# 2002-01-14, Close, 18.44
# 2002-01-15, Close, 20.16
# 2002-01-16, Close, 19.37
# 2002-01-17, Close, 20.05
# 2002-01-18, Close, 19.68
# 2002-01-18, CREATE SELl ORDER, 19.68
# 2002-01-22, SELL EXECUTED, Price: 19.87, Cost: 204.90, Comm 0.20
# 2002-01-22, OPERATION PROFIT, GROSS -6.20, NET -6.60
# 2002-01-22, Close, 19.19
# 2002-01-22, CREATE BUY ORDER, 19.19
# 2002-01-23, BUY EXECUTED, Price: 19.36, Cost: 193.60, Comm 0.19
# 2002-01-23, Close, 19.55
# 2002-01-24, Close, 20.25
# 2002-01-25, Close, 20.20
# 2002-01-28, Close, 20.98
# 2002-01-29, Close, 19.95
# 2002-01-30, Close, 20.19
# 2002-01-30, CREATE SELl ORDER, 20.19
# 2002-01-31, SELL EXECUTED, Price: 20.45, Cost: 193.60, Comm 0.20
# 2002-01-31, OPERATION PROFIT, GROSS 10.90, NET 10.50
# 2002-01-31, Close, 20.28
# 2002-02-01, Close, 19.78
# 2002-02-04, Close, 18.85
# 2002-02-04, CREATE BUY ORDER, 18.85
# 2002-02-05, BUY EXECUTED, Price: 18.73, Cost: 187.30, Comm 0.19
# 2002-02-05, Close, 18.67
# 2002-02-06, Close, 19.13
# 2002-02-07, Close, 18.51
# 2002-02-08, Close, 17.81
# 2002-02-11, Close, 18.79
# 2002-02-12, Close, 19.19
# 2002-02-12, CREATE SELl ORDER, 19.19
# 2002-02-13, SELL EXECUTED, Price: 19.44, Cost: 187.30, Comm 0.19
# 2002-02-13, OPERATION PROFIT, GROSS 7.10, NET 6.72
# 2002-02-13, Close, 18.94
# 2002-02-14, Close, 19.18
# 2002-02-15, Close, 17.69
# 2002-02-19, Close, 16.52
# 2002-02-19, CREATE BUY ORDER, 16.52
# 2002-02-20, BUY EXECUTED, Price: 16.23, Cost: 162.30, Comm 0.16
# 2002-02-20, Close, 17.38
# 2002-02-21, Close, 16.20
# 2002-02-22, Close, 15.40
# 2002-02-25, Close, 16.61
# 2002-02-26, Close, 16.97
# 2002-02-27, Close, 16.40
# 2002-02-27, CREATE SELl ORDER, 16.40
# 2002-02-28, SELL EXECUTED, Price: 16.29, Cost: 162.30, Comm 0.16
# 2002-02-28, OPERATION PROFIT, GROSS 0.60, NET 0.27
# 2002-02-28, Close, 15.74
# 2002-02-28, CREATE BUY ORDER, 15.74
# 2002-03-01, BUY EXECUTED, Price: 15.89, Cost: 158.90, Comm 0.16
# 2002-03-01, Close, 17.26
# 2002-03-04, Close, 18.22
# 2002-03-05, Close, 18.17
# 2002-03-06, Close, 17.60
# 2002-03-07, Close, 17.46
# 2002-03-08, Close, 17.98
# 2002-03-08, CREATE SELl ORDER, 17.98
# 2002-03-11, SELL EXECUTED, Price: 17.79, Cost: 158.90, Comm 0.18
# 2002-03-11, OPERATION PROFIT, GROSS 19.00, NET 18.66
# 2002-03-11, Close, 17.77
# 2002-03-12, Close, 16.84
# 2002-03-12, CREATE BUY ORDER, 16.84
# 2002-03-13, BUY EXECUTED, Price: 16.68, Cost: 166.80, Comm 0.17
# 2002-03-13, Close, 16.54
# 2002-03-14, Close, 15.62
# 2002-03-15, Close, 16.28
# 2002-03-18, Close, 16.28
# 2002-03-19, Close, 15.93
# 2002-03-20, Close, 14.35
# 2002-03-20, CREATE SELl ORDER, 14.35
# 2002-03-21, SELL EXECUTED, Price: 14.60, Cost: 166.80, Comm 0.15
# 2002-03-21, OPERATION PROFIT, GROSS -20.80, NET -21.11
# 2002-03-21, Close, 15.11
# 2002-03-22, Close, 14.98
# 2002-03-25, Close, 14.21
# 2002-03-25, CREATE BUY ORDER, 14.21
# 2002-03-26, BUY EXECUTED, Price: 14.06, Cost: 140.60, Comm 0.14
# 2002-03-26, Close, 14.50
# 2002-03-27, Close, 14.04
# 2002-03-28, Close, 13.69
# 2002-04-01, Close, 13.46
# 2002-04-02, Close, 13.11
# 2002-04-03, Close, 13.36
# 2002-04-03, CREATE SELl ORDER, 13.36
# 2002-04-04, SELL EXECUTED, Price: 13.25, Cost: 140.60, Comm 0.13
# 2002-04-04, OPERATION PROFIT, GROSS -8.10, NET -8.37
# 2002-04-04, Close, 13.29
# 2002-04-05, Close, 12.99
# 2002-04-05, CREATE BUY ORDER, 12.99
# 2002-04-08, BUY EXECUTED, Price: 12.39, Cost: 123.90, Comm 0.12
# 2002-04-08, Close, 13.42
# 2002-04-09, Close, 12.57
# 2002-04-10, Close, 11.88
# 2002-04-11, Close, 11.36
# 2002-04-12, Close, 11.32
# 2002-04-15, Close, 11.77
# 2002-04-15, CREATE SELl ORDER, 11.77
# 2002-04-16, SELL EXECUTED, Price: 12.30, Cost: 123.90, Comm 0.12
# 2002-04-16, OPERATION PROFIT, GROSS -0.90, NET -1.15
# 2002-04-16, Close, 12.28
# 2002-04-17, Close, 12.43
# 2002-04-18, Close, 12.22
# 2002-04-19, Close, 11.39
# 2002-04-19, CREATE BUY ORDER, 11.39
# 2002-04-22, BUY EXECUTED, Price: 11.26, Cost: 112.60, Comm 0.11
# 2002-04-22, Close, 11.45
# 2002-04-23, Close, 10.98
# 2002-04-24, Close, 10.02
# 2002-04-25, Close, 10.41
# 2002-04-26, Close, 9.37
# 2002-04-29, Close, 10.93
# 2002-04-29, CREATE SELl ORDER, 10.93
# 2002-04-30, SELL EXECUTED, Price: 11.19, Cost: 112.60, Comm 0.11
# 2002-04-30, OPERATION PROFIT, GROSS -0.70, NET -0.92
# 2002-04-30, Close, 10.74
# 2002-05-01, Close, 10.93
# 2002-05-02, Close, 10.49
# 2002-05-03, Close, 10.10
# 2002-05-03, CREATE BUY ORDER, 10.10
# 2002-05-06, BUY EXECUTED, Price: 9.84, Cost: 98.40, Comm 0.10
# 2002-05-06, Close, 9.72
# 2002-05-07, Close, 9.96
# 2002-05-08, Close, 11.11
# 2002-05-09, Close, 10.63
# 2002-05-10, Close, 9.84
# 2002-05-13, Close, 10.43
# 2002-05-13, CREATE SELl ORDER, 10.43
# 2002-05-14, SELL EXECUTED, Price: 11.10, Cost: 98.40, Comm 0.11
# 2002-05-14, OPERATION PROFIT, GROSS 12.60, NET 12.39
# 2002-05-14, Close, 11.47
# 2002-05-15, Close, 11.69
# 2002-05-16, Close, 11.71
# 2002-05-17, Close, 12.08
# 2002-05-20, Close, 12.21
# 2002-05-21, Close, 11.28
# 2002-05-22, Close, 11.74
# 2002-05-23, Close, 11.02
# 2002-05-24, Close, 10.81
# 2002-05-24, CREATE BUY ORDER, 10.81
# 2002-05-28, BUY EXECUTED, Price: 10.90, Cost: 109.00, Comm 0.11
# 2002-05-28, Close, 10.38
# 2002-05-29, Close, 10.77
# 2002-05-30, Close, 10.61
# 2002-05-31, Close, 10.32
# 2002-06-03, Close, 9.71
# 2002-06-04, Close, 10.21
# 2002-06-04, CREATE SELl ORDER, 10.21
# 2002-06-05, SELL EXECUTED, Price: 10.23, Cost: 109.00, Comm 0.10
# 2002-06-05, OPERATION PROFIT, GROSS -6.70, NET -6.91
# 2002-06-05, Close, 10.06
# 2002-06-06, Close, 10.06
# 2002-06-07, Close, 9.96
# 2002-06-10, Close, 9.88
# 2002-06-10, CREATE BUY ORDER, 9.88
# 2002-06-11, BUY EXECUTED, Price: 10.04, Cost: 100.40, Comm 0.10
# 2002-06-11, Close, 9.44
# 2002-06-12, Close, 8.62
# 2002-06-13, Close, 8.53
# 2002-06-14, Close, 8.69
# 2002-06-17, Close, 8.77
# 2002-06-18, Close, 8.72
# 2002-06-18, CREATE SELl ORDER, 8.72
# 2002-06-19, SELL EXECUTED, Price: 8.30, Cost: 100.40, Comm 0.08
# 2002-06-19, OPERATION PROFIT, GROSS -17.40, NET -17.58
# 2002-06-19, Close, 7.36
# 2002-06-19, CREATE BUY ORDER, 7.36
# 2002-06-20, BUY EXECUTED, Price: 7.37, Cost: 73.70, Comm 0.07
# 2002-06-20, Close, 7.29
# 2002-06-21, Close, 6.99
# 2002-06-24, Close, 7.12
# 2002-06-25, Close, 6.53
# 2002-06-26, Close, 6.19
# 2002-06-27, Close, 5.27
# 2002-06-27, CREATE SELl ORDER, 5.27
# 2002-06-28, SELL EXECUTED, Price: 5.18, Cost: 73.70, Comm 0.05
# 2002-06-28, OPERATION PROFIT, GROSS -21.90, NET -22.03
# 2002-06-28, Close, 5.30
# 2002-07-01, Close, 5.29
# 2002-07-02, Close, 4.95
# 2002-07-02, CREATE BUY ORDER, 4.95
# 2002-07-03, BUY EXECUTED, Price: 4.92, Cost: 49.20, Comm 0.05
# 2002-07-03, Close, 5.38
# 2002-07-05, Close, 5.86
# 2002-07-08, Close, 6.03
# 2002-07-09, Close, 5.74
# 2002-07-10, Close, 5.58
# 2002-07-11, Close, 6.15
# 2002-07-11, CREATE SELl ORDER, 6.15
# 2002-07-12, SELL EXECUTED, Price: 6.48, Cost: 49.20, Comm 0.06
# 2002-07-12, OPERATION PROFIT, GROSS 15.60, NET 15.49
# 2002-07-12, Close, 6.14
# 2002-07-15, Close, 6.75
# 2002-07-16, Close, 6.57
# 2002-07-17, Close, 6.01
# 2002-07-17, CREATE BUY ORDER, 6.01
# 2002-07-18, BUY EXECUTED, Price: 5.91, Cost: 59.10, Comm 0.06
# 2002-07-18, Close, 5.86
# 2002-07-19, Close, 5.59
# 2002-07-22, Close, 5.33
# 2002-07-23, Close, 4.94
# 2002-07-24, Close, 5.25
# 2002-07-25, Close, 4.65
# 2002-07-25, CREATE SELl ORDER, 4.65
# 2002-07-26, SELL EXECUTED, Price: 4.78, Cost: 59.10, Comm 0.05
# 2002-07-26, OPERATION PROFIT, GROSS -11.30, NET -11.41
# 2002-07-26, Close, 4.54
# 2002-07-26, CREATE BUY ORDER, 4.54
# 2002-07-29, BUY EXECUTED, Price: 4.73, Cost: 47.30, Comm 0.05
# 2002-07-29, Close, 4.66
# 2002-07-30, Close, 5.00
# 2002-07-31, Close, 3.42
# 2002-08-01, Close, 3.09
# 2002-08-02, Close, 2.88
# 2002-08-05, Close, 2.65
# 2002-08-05, CREATE SELl ORDER, 2.65
# 2002-08-06, SELL EXECUTED, Price: 2.78, Cost: 47.30, Comm 0.03
# 2002-08-06, OPERATION PROFIT, GROSS -19.50, NET -19.58
# 2002-08-06, Close, 2.79
# 2002-08-07, Close, 2.73
# 2002-08-08, Close, 2.91
# 2002-08-09, Close, 2.84
# 2002-08-12, Close, 2.84
# 2002-08-13, Close, 2.78
# 2002-08-14, Close, 2.97
# 2002-08-15, Close, 3.17
# 2002-08-16, Close, 3.30
# 2002-08-19, Close, 3.90
# 2002-08-20, Close, 3.73
# 2002-08-21, Close, 3.93
# 2002-08-22, Close, 3.79
# 2002-08-23, Close, 3.54
# 2002-08-23, CREATE BUY ORDER, 3.54
# 2002-08-26, BUY EXECUTED, Price: 3.61, Cost: 36.10, Comm 0.04
# 2002-08-26, Close, 3.57
# 2002-08-27, Close, 3.37
# 2002-08-28, Close, 3.16
# 2002-08-29, Close, 3.20
# 2002-08-30, Close, 3.12
# 2002-09-03, Close, 2.92
# 2002-09-03, CREATE SELl ORDER, 2.92
# 2002-09-04, SELL EXECUTED, Price: 2.93, Cost: 36.10, Comm 0.03
# 2002-09-04, OPERATION PROFIT, GROSS -6.80, NET -6.87
# 2002-09-04, Close, 2.91
# 2002-09-04, CREATE BUY ORDER, 2.91
# 2002-09-05, BUY EXECUTED, Price: 2.88, Cost: 28.80, Comm 0.03
# 2002-09-05, Close, 2.80
# 2002-09-06, Close, 2.86
# 2002-09-09, Close, 2.85
# 2002-09-10, Close, 3.26
# 2002-09-11, Close, 3.42
# 2002-09-12, Close, 3.31
# 2002-09-12, CREATE SELl ORDER, 3.31
# 2002-09-13, SELL EXECUTED, Price: 3.28, Cost: 28.80, Comm 0.03
# 2002-09-13, OPERATION PROFIT, GROSS 4.00, NET 3.94
# 2002-09-13, Close, 3.26
# 2002-09-13, CREATE BUY ORDER, 3.26
# 2002-09-16, BUY EXECUTED, Price: 3.21, Cost: 32.10, Comm 0.03
# 2002-09-16, Close, 3.05
# 2002-09-17, Close, 3.01
# 2002-09-18, Close, 2.92
# 2002-09-19, Close, 2.83
# 2002-09-20, Close, 2.84
# 2002-09-23, Close, 2.72
# 2002-09-23, CREATE SELl ORDER, 2.72
# 2002-09-24, SELL EXECUTED, Price: 2.69, Cost: 32.10, Comm 0.03
# 2002-09-24, OPERATION PROFIT, GROSS -5.20, NET -5.26
# 2002-09-24, Close, 2.74
# 2002-09-25, Close, 2.89
# 2002-09-26, Close, 2.74
# 2002-09-27, Close, 2.64
# 2002-09-27, CREATE BUY ORDER, 2.64
# 2002-09-30, BUY EXECUTED, Price: 2.63, Cost: 26.30, Comm 0.03
# 2002-09-30, Close, 2.64
# 2002-10-01, Close, 2.78
# 2002-10-02, Close, 2.78
# 2002-10-03, Close, 2.64
# 2002-10-04, Close, 2.51
# 2002-10-07, Close, 2.39
# 2002-10-07, CREATE SELl ORDER, 2.39
# 2002-10-08, SELL EXECUTED, Price: 2.47, Cost: 26.30, Comm 0.02
# 2002-10-08, OPERATION PROFIT, GROSS -1.60, NET -1.65
# 2002-10-08, Close, 2.32
# 2002-10-08, CREATE BUY ORDER, 2.32
# 2002-10-09, BUY EXECUTED, Price: 2.28, Cost: 22.80, Comm 0.02
# 2002-10-09, Close, 2.27
# 2002-10-10, Close, 2.39
# 2002-10-11, Close, 2.72
# 2002-10-14, Close, 2.64
# 2002-10-15, Close, 2.91
# 2002-10-16, Close, 2.67
# 2002-10-16, CREATE SELl ORDER, 2.67
# 2002-10-17, SELL EXECUTED, Price: 2.90, Cost: 22.80, Comm 0.03
# 2002-10-17, OPERATION PROFIT, GROSS 6.20, NET 6.15
# 2002-10-17, Close, 2.87
# 2002-10-18, Close, 2.90
# 2002-10-21, Close, 3.16
# 2002-10-22, Close, 3.27
# 2002-10-23, Close, 3.40
# 2002-10-24, Close, 3.23
# 2002-10-25, Close, 3.42
# 2002-10-28, Close, 3.44
# 2002-10-29, Close, 3.29
# 2002-10-30, Close, 3.47
# 2002-10-31, Close, 3.67
# 2002-11-01, Close, 4.35
# 2002-11-04, Close, 4.83
# 2002-11-05, Close, 4.63
# 2002-11-06, Close, 4.99
# 2002-11-07, Close, 4.49
# 2002-11-08, Close, 3.50
# 2002-11-08, CREATE BUY ORDER, 3.50
# 2002-11-11, BUY EXECUTED, Price: 3.34, Cost: 33.40, Comm 0.03
# 2002-11-11, Close, 3.23
# 2002-11-12, Close, 3.52
# 2002-11-13, Close, 3.63
# 2002-11-14, Close, 3.87
# 2002-11-15, Close, 4.16
# 2002-11-18, Close, 4.31
# 2002-11-18, CREATE SELl ORDER, 4.31
# 2002-11-19, SELL EXECUTED, Price: 4.29, Cost: 33.40, Comm 0.04
# 2002-11-19, OPERATION PROFIT, GROSS 9.50, NET 9.42
# 2002-11-19, Close, 4.37
# 2002-11-20, Close, 4.59
# 2002-11-21, Close, 4.98
# 2002-11-22, Close, 4.85
# 2002-11-25, Close, 5.03
# 2002-11-26, Close, 4.89
# 2002-11-27, Close, 5.27
# 2002-11-29, Close, 5.28
# 2002-12-02, Close, 5.24
# 2002-12-03, Close, 4.90
# 2002-12-03, CREATE BUY ORDER, 4.90
# 2002-12-04, BUY EXECUTED, Price: 4.55, Cost: 45.50, Comm 0.05
# 2002-12-04, Close, 4.31
# 2002-12-05, Close, 4.35
# 2002-12-06, Close, 4.36
# 2002-12-09, Close, 4.01
# 2002-12-10, Close, 4.35
# 2002-12-11, Close, 4.32
# 2002-12-11, CREATE SELl ORDER, 4.32
# 2002-12-12, SELL EXECUTED, Price: 4.48, Cost: 45.50, Comm 0.04
# 2002-12-12, OPERATION PROFIT, GROSS -0.70, NET -0.79
# 2002-12-12, Close, 4.25
# 2002-12-12, CREATE BUY ORDER, 4.25
# 2002-12-13, BUY EXECUTED, Price: 4.17, Cost: 41.70, Comm 0.04
# 2002-12-13, Close, 4.08
# 2002-12-16, Close, 4.33
# 2002-12-17, Close, 4.32
# 2002-12-18, Close, 3.99
# 2002-12-19, Close, 3.90
# 2002-12-20, Close, 3.96
# 2002-12-20, CREATE SELl ORDER, 3.96
# 2002-12-23, SELL EXECUTED, Price: 3.95, Cost: 41.70, Comm 0.04
# 2002-12-23, OPERATION PROFIT, GROSS -2.20, NET -2.28
# 2002-12-23, Close, 3.98
# 2002-12-24, Close, 3.90
# 2002-12-26, Close, 3.83
# 2002-12-26, CREATE BUY ORDER, 3.83
# 2002-12-27, BUY EXECUTED, Price: 3.94, Cost: 39.40, Comm 0.04
# 2002-12-27, Close, 3.69
# 2002-12-30, Close, 3.56
# 2002-12-31, Close, 3.55
# 2003-01-02, Close, 3.80
# 2003-01-03, Close, 3.80
# 2003-01-06, Close, 4.11
# 2003-01-06, CREATE SELl ORDER, 4.11
# 2003-01-07, SELL EXECUTED, Price: 4.19, Cost: 39.40, Comm 0.04
# 2003-01-07, OPERATION PROFIT, GROSS 2.50, NET 2.42
# 2003-01-07, Close, 4.09
# 2003-01-08, Close, 3.69
# 2003-01-08, CREATE BUY ORDER, 3.69
# 2003-01-09, BUY EXECUTED, Price: 3.80, Cost: 38.00, Comm 0.04
# 2003-01-09, Close, 3.75
# 2003-01-10, Close, 3.82
# 2003-01-13, Close, 3.79
# 2003-01-14, Close, 3.81
# 2003-01-15, Close, 3.70
# 2003-01-16, Close, 3.45
# 2003-01-16, CREATE SELl ORDER, 3.45
# 2003-01-17, SELL EXECUTED, Price: 3.35, Cost: 38.00, Comm 0.03
# 2003-01-17, OPERATION PROFIT, GROSS -4.50, NET -4.57
# 2003-01-17, Close, 3.32
# 2003-01-17, CREATE BUY ORDER, 3.32
# 2003-01-21, BUY EXECUTED, Price: 3.38, Cost: 33.80, Comm 0.03
# 2003-01-21, Close, 3.23
# 2003-01-22, Close, 3.24
# 2003-01-23, Close, 3.33
# 2003-01-24, Close, 3.14
# 2003-01-27, Close, 3.09
# 2003-01-28, Close, 3.20
# 2003-01-28, CREATE SELl ORDER, 3.20
# 2003-01-29, SELL EXECUTED, Price: 3.12, Cost: 33.80, Comm 0.03
# 2003-01-29, OPERATION PROFIT, GROSS -2.60, NET -2.66
# 2003-01-29, Close, 3.27
# 2003-01-30, Close, 3.13
# 2003-01-31, Close, 3.18
# 2003-02-03, Close, 3.25
# 2003-02-04, Close, 3.10
# 2003-02-05, Close, 3.13
# 2003-02-06, Close, 3.15
# 2003-02-07, Close, 3.01
# 2003-02-10, Close, 3.05
# 2003-02-11, Close, 2.99
# 2003-02-12, Close, 3.01
# 2003-02-13, Close, 3.04
# 2003-02-14, Close, 3.71
# 2003-02-18, Close, 3.93
# 2003-02-19, Close, 3.96
# 2003-02-20, Close, 3.96
# 2003-02-21, Close, 3.97
# 2003-02-24, Close, 4.02
# 2003-02-25, Close, 3.99
# 2003-02-26, Close, 3.80
# 2003-02-26, CREATE BUY ORDER, 3.80
# 2003-02-27, BUY EXECUTED, Price: 3.83, Cost: 38.30, Comm 0.04
# 2003-02-27, Close, 3.88
# 2003-02-28, Close, 3.89
# 2003-03-03, Close, 3.83
# 2003-03-04, Close, 3.80
# 2003-03-05, Close, 3.86
# 2003-03-06, Close, 3.79
# 2003-03-06, CREATE SELl ORDER, 3.79
# 2003-03-07, SELL EXECUTED, Price: 3.74, Cost: 38.30, Comm 0.04
# 2003-03-07, OPERATION PROFIT, GROSS -0.90, NET -0.98
# 2003-03-07, Close, 3.85
# 2003-03-10, Close, 3.75
# 2003-03-11, Close, 3.77
# 2003-03-12, Close, 3.88
# 2003-03-13, Close, 4.26
# 2003-03-14, Close, 4.14
# 2003-03-17, Close, 4.38
# 2003-03-18, Close, 4.35
# 2003-03-19, Close, 4.37
# 2003-03-20, Close, 4.41
# 2003-03-21, Close, 4.37
# 2003-03-24, Close, 4.20
# 2003-03-24, CREATE BUY ORDER, 4.20
# 2003-03-25, BUY EXECUTED, Price: 4.22, Cost: 42.20, Comm 0.04
# 2003-03-25, Close, 4.33
# 2003-03-26, Close, 4.45
# 2003-03-27, Close, 4.32
# 2003-03-28, Close, 4.14
# 2003-03-31, Close, 3.97
# 2003-04-01, Close, 4.09
# 2003-04-01, CREATE SELl ORDER, 4.09
# 2003-04-02, SELL EXECUTED, Price: 4.23, Cost: 42.20, Comm 0.04
# 2003-04-02, OPERATION PROFIT, GROSS 0.10, NET 0.02
# 2003-04-02, Close, 4.24
# 2003-04-03, Close, 4.30
# 2003-04-04, Close, 4.13
# 2003-04-07, Close, 4.17
# 2003-04-08, Close, 4.13
# 2003-04-09, Close, 4.11
# 2003-04-09, CREATE BUY ORDER, 4.11
# 2003-04-10, BUY EXECUTED, Price: 4.17, Cost: 41.70, Comm 0.04
# 2003-04-10, Close, 4.13
# 2003-04-11, Close, 4.09
# 2003-04-14, Close, 4.16
# 2003-04-15, Close, 4.14
# 2003-04-16, Close, 4.14
# 2003-04-17, Close, 4.21
# 2003-04-17, CREATE SELl ORDER, 4.21
# 2003-04-21, SELL EXECUTED, Price: 4.22, Cost: 41.70, Comm 0.04
# 2003-04-21, OPERATION PROFIT, GROSS 0.50, NET 0.42
# 2003-04-21, Close, 4.32
# 2003-04-22, Close, 4.37
# 2003-04-23, Close, 4.47
# 2003-04-24, Close, 4.34
# 2003-04-25, Close, 4.18
# 2003-04-25, CREATE BUY ORDER, 4.18
# 2003-04-28, BUY EXECUTED, Price: 4.23, Cost: 42.30, Comm 0.04
# 2003-04-28, Close, 4.31
# 2003-04-29, Close, 4.44
# 2003-04-30, Close, 4.42
# 2003-05-01, Close, 4.45
# 2003-05-02, Close, 4.91
# 2003-05-05, Close, 5.03
# 2003-05-05, CREATE SELl ORDER, 5.03
# 2003-05-06, SELL EXECUTED, Price: 5.00, Cost: 42.30, Comm 0.05
# 2003-05-06, OPERATION PROFIT, GROSS 7.70, NET 7.61
# 2003-05-06, Close, 5.03
# 2003-05-07, Close, 4.95
# 2003-05-08, Close, 4.95
# 2003-05-09, Close, 6.59
# 2003-05-12, Close, 6.41
# 2003-05-13, Close, 6.29
# 2003-05-13, CREATE BUY ORDER, 6.29
# 2003-05-14, BUY EXECUTED, Price: 6.31, Cost: 63.10, Comm 0.06
# 2003-05-14, Close, 6.28
# 2003-05-15, Close, 6.50
# 2003-05-16, Close, 6.56
# 2003-05-19, Close, 6.19
# 2003-05-20, Close, 6.23
# 2003-05-21, Close, 6.45
# 2003-05-21, CREATE SELl ORDER, 6.45
# 2003-05-22, SELL EXECUTED, Price: 6.46, Cost: 63.10, Comm 0.06
# 2003-05-22, OPERATION PROFIT, GROSS 1.50, NET 1.37
# 2003-05-22, Close, 6.47
# 2003-05-23, Close, 6.44
# 2003-05-27, Close, 7.01
# 2003-05-28, Close, 6.99
# 2003-05-29, Close, 7.47
# 2003-05-30, Close, 8.07
# 2003-06-02, Close, 7.63
# 2003-06-03, Close, 7.78
# 2003-06-04, Close, 7.97
# 2003-06-05, Close, 8.20
# 2003-06-06, Close, 7.95
# 2003-06-09, Close, 7.85
# 2003-06-09, CREATE BUY ORDER, 7.85
# 2003-06-10, BUY EXECUTED, Price: 7.85, Cost: 78.50, Comm 0.08
# 2003-06-10, Close, 7.97
# 2003-06-11, Close, 7.97
# 2003-06-12, Close, 7.85
# 2003-06-13, Close, 7.24
# 2003-06-16, Close, 7.39
# 2003-06-17, Close, 7.57
# 2003-06-17, CREATE SELl ORDER, 7.57
# ...
# 2008-12-04, Close, 6.55
# 2008-12-05, Close, 6.81
# 2008-12-08, Close, 6.59
# 2008-12-09, Close, 7.23
# 2008-12-09, CREATE SELl ORDER, 7.23
# 2008-12-10, SELL EXECUTED, Price: 7.37, Cost: 64.40, Comm 0.07
# 2008-12-10, OPERATION PROFIT, GROSS 9.30, NET 9.16
# 2008-12-10, Close, 7.91
# 2008-12-11, Close, 7.58
# 2008-12-12, Close, 7.96
# 2008-12-15, Close, 7.70
# 2008-12-16, Close, 8.22
# 2008-12-17, Close, 8.63
# 2008-12-18, Close, 7.83
# 2008-12-19, Close, 7.89
# 2008-12-22, Close, 7.42
# 2008-12-23, Close, 7.32
# 2008-12-23, CREATE BUY ORDER, 7.32
# 2008-12-24, BUY EXECUTED, Price: 7.17, Cost: 71.70, Comm 0.07
# 2008-12-24, Close, 7.14
# 2008-12-26, Close, 6.95
# 2008-12-29, Close, 7.17
# 2008-12-30, Close, 7.42
# 2008-12-31, Close, 7.47
# 2009-01-02, Close, 8.06
# 2009-01-02, CREATE SELl ORDER, 8.06
# 2009-01-05, SELL EXECUTED, Price: 7.97, Cost: 71.70, Comm 0.08
# 2009-01-05, OPERATION PROFIT, GROSS 8.00, NET 7.85
# 2009-01-05, Close, 8.21
# 2009-01-06, Close, 8.49
# 2009-01-07, Close, 7.98
# 2009-01-08, Close, 7.77
# 2009-01-08, CREATE BUY ORDER, 7.77
# 2009-01-09, BUY EXECUTED, Price: 7.77, Cost: 77.70, Comm 0.08
# 2009-01-09, Close, 7.34
# 2009-01-12, Close, 7.04
# 2009-01-13, Close, 7.08
# 2009-01-14, Close, 6.77
# 2009-01-15, Close, 7.01
# 2009-01-16, Close, 7.39
# 2009-01-16, CREATE SELl ORDER, 7.39
# 2009-01-20, SELL EXECUTED, Price: 7.38, Cost: 77.70, Comm 0.07
# 2009-01-20, OPERATION PROFIT, GROSS -3.90, NET -4.05
# 2009-01-20, Close, 6.67
# 2009-01-21, Close, 7.00
# 2009-01-22, Close, 6.87
# 2009-01-23, Close, 7.14
# 2009-01-26, Close, 7.38
# 2009-01-27, Close, 7.81
# 2009-01-28, Close, 8.14
# 2009-01-29, Close, 7.66
# 2009-01-30, Close, 7.36
# 2009-01-30, CREATE BUY ORDER, 7.36
# 2009-02-02, BUY EXECUTED, Price: 7.25, Cost: 72.50, Comm 0.07
# 2009-02-02, Close, 7.76
# 2009-02-03, Close, 7.85
# 2009-02-04, Close, 8.07
# 2009-02-05, Close, 8.66
# 2009-02-06, Close, 9.13
# 2009-02-09, Close, 9.01
# 2009-02-09, CREATE SELl ORDER, 9.01
# 2009-02-10, SELL EXECUTED, Price: 9.01, Cost: 72.50, Comm 0.09
# 2009-02-10, OPERATION PROFIT, GROSS 17.60, NET 17.44
# 2009-02-10, Close, 8.63
# 2009-02-10, CREATE BUY ORDER, 8.63
# 2009-02-11, BUY EXECUTED, Price: 7.94, Cost: 79.40, Comm 0.08
# 2009-02-11, Close, 7.54
# 2009-02-12, Close, 7.70
# 2009-02-13, Close, 7.69
# 2009-02-17, Close, 7.25
# 2009-02-18, Close, 7.44
# 2009-02-19, Close, 6.87
# 2009-02-19, CREATE SELl ORDER, 6.87
# 2009-02-20, SELL EXECUTED, Price: 6.77, Cost: 79.40, Comm 0.07
# 2009-02-20, OPERATION PROFIT, GROSS -11.70, NET -11.85
# 2009-02-20, Close, 7.04
# 2009-02-23, Close, 6.72
# 2009-02-24, Close, 7.32
# 2009-02-25, Close, 7.40
# 2009-02-26, Close, 7.64
# 2009-02-27, Close, 7.66
# 2009-03-02, Close, 7.02
# 2009-03-03, Close, 7.29
# 2009-03-04, Close, 7.83
# 2009-03-05, Close, 7.64
# 2009-03-06, Close, 7.77
# 2009-03-09, Close, 7.68
# 2009-03-10, Close, 8.38
# 2009-03-11, Close, 8.61
# 2009-03-12, Close, 9.12
# 2009-03-13, Close, 9.07
# 2009-03-16, Close, 8.72
# 2009-03-16, CREATE BUY ORDER, 8.72
# 2009-03-17, BUY EXECUTED, Price: 8.75, Cost: 87.50, Comm 0.09
# 2009-03-17, Close, 9.15
# 2009-03-18, Close, 9.44
# 2009-03-19, Close, 9.33
# 2009-03-20, Close, 8.82
# 2009-03-23, Close, 9.46
# 2009-03-24, Close, 9.05
# 2009-03-24, CREATE SELl ORDER, 9.05
# 2009-03-25, SELL EXECUTED, Price: 9.33, Cost: 87.50, Comm 0.09
# 2009-03-25, OPERATION PROFIT, GROSS 5.80, NET 5.62
# 2009-03-25, Close, 9.20
# 2009-03-26, Close, 9.77
# 2009-03-27, Close, 9.68
# 2009-03-30, Close, 9.06
# 2009-03-30, CREATE BUY ORDER, 9.06
# 2009-03-31, BUY EXECUTED, Price: 9.20, Cost: 92.00, Comm 0.09
# 2009-03-31, Close, 9.13
# 2009-04-01, Close, 9.36
# 2009-04-02, Close, 9.79
# 2009-04-03, Close, 10.48
# 2009-04-06, Close, 10.50
# 2009-04-07, Close, 10.14
# 2009-04-07, CREATE SELl ORDER, 10.14
# 2009-04-08, SELL EXECUTED, Price: 10.25, Cost: 92.00, Comm 0.10
# 2009-04-08, OPERATION PROFIT, GROSS 10.50, NET 10.31
# 2009-04-08, Close, 10.56
# 2009-04-09, Close, 11.14
# 2009-04-13, Close, 10.78
# 2009-04-14, Close, 10.85
# 2009-04-15, Close, 10.54
# 2009-04-16, Close, 10.81
# 2009-04-17, Close, 10.88
# 2009-04-20, Close, 10.23
# 2009-04-21, Close, 10.20
# 2009-04-21, CREATE BUY ORDER, 10.20
# 2009-04-22, BUY EXECUTED, Price: 10.11, Cost: 101.10, Comm 0.10
# 2009-04-22, Close, 10.50
# 2009-04-23, Close, 10.34
# 2009-04-24, Close, 10.58
# 2009-04-27, Close, 10.20
# 2009-04-28, Close, 10.23
# 2009-04-29, Close, 10.07
# 2009-04-29, CREATE SELl ORDER, 10.07
# 2009-04-30, SELL EXECUTED, Price: 10.26, Cost: 101.10, Comm 0.10
# 2009-04-30, OPERATION PROFIT, GROSS 1.50, NET 1.30
# 2009-04-30, Close, 10.62
# 2009-05-01, Close, 10.80
# 2009-05-04, Close, 11.38
# 2009-05-05, Close, 10.92
# 2009-05-06, Close, 10.70
# 2009-05-06, CREATE BUY ORDER, 10.70
# 2009-05-07, BUY EXECUTED, Price: 10.94, Cost: 109.40, Comm 0.11
# 2009-05-07, Close, 9.93
# 2009-05-08, Close, 8.56
# 2009-05-11, Close, 8.73
# 2009-05-12, Close, 8.31
# 2009-05-13, Close, 7.77
# 2009-05-14, Close, 7.89
# 2009-05-14, CREATE SELl ORDER, 7.89
# 2009-05-15, SELL EXECUTED, Price: 7.94, Cost: 109.40, Comm 0.08
# 2009-05-15, OPERATION PROFIT, GROSS -30.00, NET -30.19
# 2009-05-15, Close, 8.09
# 2009-05-18, Close, 8.58
# 2009-05-19, Close, 8.75
# 2009-05-20, Close, 9.01
# 2009-05-21, Close, 8.95
# 2009-05-22, Close, 9.09
# 2009-05-26, Close, 9.58
# 2009-05-27, Close, 9.60
# 2009-05-28, Close, 9.73
# 2009-05-29, Close, 9.65
# 2009-06-01, Close, 10.13
# 2009-06-02, Close, 10.04
# 2009-06-03, Close, 9.73
# 2009-06-03, CREATE BUY ORDER, 9.73
# 2009-06-04, BUY EXECUTED, Price: 9.75, Cost: 97.50, Comm 0.10
# 2009-06-04, Close, 10.08
# 2009-06-05, Close, 10.02
# 2009-06-08, Close, 9.97
# 2009-06-09, Close, 10.51
# 2009-06-10, Close, 10.85
# 2009-06-11, Close, 10.71
# 2009-06-11, CREATE SELl ORDER, 10.71
# 2009-06-12, SELL EXECUTED, Price: 10.55, Cost: 97.50, Comm 0.11
# 2009-06-12, OPERATION PROFIT, GROSS 8.00, NET 7.80
# 2009-06-12, Close, 10.65
# 2009-06-12, CREATE BUY ORDER, 10.65
# 2009-06-15, BUY EXECUTED, Price: 10.46, Cost: 104.60, Comm 0.10
# 2009-06-15, Close, 10.48
# 2009-06-16, Close, 10.19
# 2009-06-17, Close, 10.44
# 2009-06-18, Close, 10.24
# 2009-06-19, Close, 10.35
# 2009-06-22, Close, 9.76
# 2009-06-22, CREATE SELl ORDER, 9.76
# 2009-06-23, SELL EXECUTED, Price: 9.86, Cost: 104.60, Comm 0.10
# 2009-06-23, OPERATION PROFIT, GROSS -6.00, NET -6.20
# 2009-06-23, Close, 9.72
# 2009-06-23, CREATE BUY ORDER, 9.72
# 2009-06-24, BUY EXECUTED, Price: 9.84, Cost: 98.40, Comm 0.10
# 2009-06-24, Close, 10.04
# 2009-06-25, Close, 10.57
# 2009-06-26, Close, 10.71
# 2009-06-29, Close, 10.71
# 2009-06-30, Close, 10.45
# 2009-07-01, Close, 10.50
# 2009-07-01, CREATE SELl ORDER, 10.50
# 2009-07-02, SELL EXECUTED, Price: 10.15, Cost: 98.40, Comm 0.10
# 2009-07-02, OPERATION PROFIT, GROSS 3.10, NET 2.90
# 2009-07-02, Close, 10.09
# 2009-07-06, Close, 9.76
# 2009-07-06, CREATE BUY ORDER, 9.76
# 2009-07-07, BUY EXECUTED, Price: 9.80, Cost: 98.00, Comm 0.10
# 2009-07-07, Close, 9.34
# 2009-07-08, Close, 9.36
# 2009-07-09, Close, 9.56
# 2009-07-10, Close, 9.60
# 2009-07-13, Close, 9.71
# 2009-07-14, Close, 9.91
# 2009-07-14, CREATE SELl ORDER, 9.91
# 2009-07-15, SELL EXECUTED, Price: 10.27, Cost: 98.00, Comm 0.10
# 2009-07-15, OPERATION PROFIT, GROSS 4.70, NET 4.50
# 2009-07-15, Close, 10.32
# 2009-07-16, Close, 10.86
# 2009-07-17, Close, 11.17
# 2009-07-20, Close, 11.31
# 2009-07-21, Close, 11.08
# 2009-07-22, Close, 11.36
# 2009-07-23, Close, 12.03
# 2009-07-24, Close, 11.99
# 2009-07-27, Close, 12.05
# 2009-07-28, Close, 12.07
# 2009-07-29, Close, 11.83
# 2009-07-30, Close, 11.92
# 2009-07-31, Close, 11.97
# 2009-08-03, Close, 12.29
# 2009-08-04, Close, 12.37
# 2009-08-05, Close, 12.40
# 2009-08-06, Close, 12.14
# 2009-08-07, Close, 12.69
# 2009-08-10, Close, 12.27
# 2009-08-11, Close, 11.99
# 2009-08-11, CREATE BUY ORDER, 11.99
# 2009-08-12, BUY EXECUTED, Price: 11.99, Cost: 119.90, Comm 0.12
# 2009-08-12, Close, 12.43
# 2009-08-13, Close, 12.80
# 2009-08-14, Close, 12.42
# 2009-08-17, Close, 11.90
# 2009-08-18, Close, 12.34
# 2009-08-19, Close, 12.20
# 2009-08-19, CREATE SELl ORDER, 12.20
# 2009-08-20, SELL EXECUTED, Price: 12.14, Cost: 119.90, Comm 0.12
# 2009-08-20, OPERATION PROFIT, GROSS 1.50, NET 1.26
# 2009-08-20, Close, 12.68
# 2009-08-21, Close, 12.89
# 2009-08-24, Close, 12.53
# 2009-08-25, Close, 12.64
# 2009-08-26, Close, 12.79
# 2009-08-27, Close, 12.97
# 2009-08-28, Close, 13.63
# 2009-08-31, Close, 13.44
# 2009-09-01, Close, 12.98
# 2009-09-01, CREATE BUY ORDER, 12.98
# 2009-09-02, BUY EXECUTED, Price: 13.00, Cost: 130.00, Comm 0.13
# 2009-09-02, Close, 13.17
# 2009-09-03, Close, 13.48
# 2009-09-04, Close, 13.98
# 2009-09-08, Close, 14.37
# 2009-09-09, Close, 14.77
# 2009-09-10, Close, 15.24
# 2009-09-10, CREATE SELl ORDER, 15.24
# 2009-09-11, SELL EXECUTED, Price: 15.21, Cost: 130.00, Comm 0.15
# 2009-09-11, OPERATION PROFIT, GROSS 22.10, NET 21.82
# 2009-09-11, Close, 15.10
# 2009-09-14, Close, 14.85
# 2009-09-14, CREATE BUY ORDER, 14.85
# 2009-09-15, BUY EXECUTED, Price: 14.99, Cost: 149.90, Comm 0.15
# 2009-09-15, Close, 15.16
# 2009-09-16, Close, 14.75
# 2009-09-17, Close, 14.10
# 2009-09-18, Close, 14.09
# 2009-09-21, Close, 14.02
# 2009-09-22, Close, 14.05
# 2009-09-22, CREATE SELl ORDER, 14.05
# 2009-09-23, SELL EXECUTED, Price: 14.13, Cost: 149.90, Comm 0.14
# 2009-09-23, OPERATION PROFIT, GROSS -8.60, NET -8.89
# 2009-09-23, Close, 13.83
# 2009-09-24, Close, 13.64
# 2009-09-24, CREATE BUY ORDER, 13.64
# 2009-09-25, BUY EXECUTED, Price: 13.57, Cost: 135.70, Comm 0.14
# 2009-09-25, Close, 13.42
# 2009-09-28, Close, 13.73
# 2009-09-29, Close, 13.48
# 2009-09-30, Close, 13.91
# 2009-10-01, Close, 12.92
# 2009-10-02, Close, 12.82
# 2009-10-02, CREATE SELl ORDER, 12.82
# 2009-10-05, SELL EXECUTED, Price: 12.96, Cost: 135.70, Comm 0.13
# 2009-10-05, OPERATION PROFIT, GROSS -6.10, NET -6.37
# 2009-10-05, Close, 12.75
# 2009-10-05, CREATE BUY ORDER, 12.75
# 2009-10-06, BUY EXECUTED, Price: 12.91, Cost: 129.10, Comm 0.13
# 2009-10-06, Close, 12.97
# 2009-10-07, Close, 12.86
# 2009-10-08, Close, 12.95
# 2009-10-09, Close, 13.11
# 2009-10-12, Close, 12.97
# 2009-10-13, Close, 12.92
# 2009-10-13, CREATE SELl ORDER, 12.92
# 2009-10-14, SELL EXECUTED, Price: 13.42, Cost: 129.10, Comm 0.13
# 2009-10-14, OPERATION PROFIT, GROSS 5.10, NET 4.84
# 2009-10-14, Close, 12.90
# 2009-10-14, CREATE BUY ORDER, 12.90
# 2009-10-15, BUY EXECUTED, Price: 12.88, Cost: 128.80, Comm 0.13
# 2009-10-15, Close, 12.52
# 2009-10-16, Close, 12.24
# 2009-10-19, Close, 12.68
# 2009-10-20, Close, 12.69
# 2009-10-21, Close, 12.38
# 2009-10-22, Close, 12.47
# 2009-10-22, CREATE SELl ORDER, 12.47
# 2009-10-23, SELL EXECUTED, Price: 12.63, Cost: 128.80, Comm 0.13
# 2009-10-23, OPERATION PROFIT, GROSS -2.50, NET -2.76
# 2009-10-23, Close, 12.17
# 2009-10-26, Close, 12.01
# 2009-10-26, CREATE BUY ORDER, 12.01
# 2009-10-27, BUY EXECUTED, Price: 11.96, Cost: 119.60, Comm 0.12
# 2009-10-27, Close, 11.61
# 2009-10-28, Close, 11.12
# 2009-10-29, Close, 11.62
# 2009-10-30, Close, 11.07
# 2009-11-02, Close, 11.17
# 2009-11-03, Close, 11.12
# 2009-11-03, CREATE SELl ORDER, 11.12
# 2009-11-04, SELL EXECUTED, Price: 11.20, Cost: 119.60, Comm 0.11
# 2009-11-04, OPERATION PROFIT, GROSS -7.60, NET -7.83
# 2009-11-04, Close, 11.09
# 2009-11-04, CREATE BUY ORDER, 11.09
# 2009-11-05, BUY EXECUTED, Price: 11.22, Cost: 112.20, Comm 0.11
# 2009-11-05, Close, 11.36
# 2009-11-06, Close, 12.18
# 2009-11-09, Close, 12.46
# 2009-11-10, Close, 12.15
# 2009-11-11, Close, 12.49
# 2009-11-12, Close, 12.46
# 2009-11-12, CREATE SELl ORDER, 12.46
# 2009-11-13, SELL EXECUTED, Price: 12.45, Cost: 112.20, Comm 0.12
# 2009-11-13, OPERATION PROFIT, GROSS 12.30, NET 12.06
# 2009-11-13, Close, 12.55
# 2009-11-16, Close, 12.73
# 2009-11-17, Close, 12.71
# 2009-11-18, Close, 12.51
# 2009-11-18, CREATE BUY ORDER, 12.51
# 2009-11-19, BUY EXECUTED, Price: 12.24, Cost: 122.40, Comm 0.12
# 2009-11-19, Close, 12.01
# 2009-11-20, Close, 11.94
# 2009-11-23, Close, 12.03
# 2009-11-24, Close, 11.96
# 2009-11-25, Close, 12.10
# 2009-11-27, Close, 11.84
# 2009-11-27, CREATE SELl ORDER, 11.84
# 2009-11-30, SELL EXECUTED, Price: 11.88, Cost: 122.40, Comm 0.12
# 2009-11-30, OPERATION PROFIT, GROSS -3.60, NET -3.84
# 2009-11-30, Close, 12.09
# 2009-12-01, Close, 12.33
# 2009-12-02, Close, 12.70
# 2009-12-03, Close, 12.80
# 2009-12-04, Close, 13.20
# 2009-12-07, Close, 14.89
# 2009-12-08, Close, 14.17
# 2009-12-09, Close, 14.52
# 2009-12-10, Close, 14.26
# 2009-12-11, Close, 14.08
# 2009-12-11, CREATE BUY ORDER, 14.08
# 2009-12-14, BUY EXECUTED, Price: 14.28, Cost: 142.80, Comm 0.14
# 2009-12-14, Close, 14.50
# 2009-12-15, Close, 14.48
# 2009-12-16, Close, 15.65
# 2009-12-17, Close, 15.58
# 2009-12-18, Close, 15.57
# 2009-12-21, Close, 16.12
# 2009-12-21, CREATE SELl ORDER, 16.12
# 2009-12-22, SELL EXECUTED, Price: 16.12, Cost: 142.80, Comm 0.16
# 2009-12-22, OPERATION PROFIT, GROSS 18.40, NET 18.10
# 2009-12-22, Close, 16.55
# 2009-12-23, Close, 16.78
# 2009-12-24, Close, 16.74
# 2009-12-28, Close, 16.47
# 2009-12-28, CREATE BUY ORDER, 16.47
# 2009-12-29, BUY EXECUTED, Price: 16.42, Cost: 164.20, Comm 0.16
# 2009-12-29, Close, 16.68
# 2009-12-30, Close, 17.28
# 2009-12-31, Close, 17.29
# 2010-01-04, Close, 17.11
# 2010-01-05, Close, 17.36
# 2010-01-06, Close, 17.47
# 2010-01-06, CREATE SELl ORDER, 17.47
# 2010-01-07, SELL EXECUTED, Price: 17.38, Cost: 164.20, Comm 0.17
# 2010-01-07, OPERATION PROFIT, GROSS 9.60, NET 9.26
# 2010-01-07, Close, 17.13
# 2010-01-08, Close, 17.17
# 2010-01-11, Close, 16.93
# 2010-01-12, Close, 16.35
# 2010-01-12, CREATE BUY ORDER, 16.35
# 2010-01-13, BUY EXECUTED, Price: 16.46, Cost: 164.60, Comm 0.16
# 2010-01-13, Close, 16.58
# 2010-01-14, Close, 16.32
# 2010-01-15, Close, 15.84
# 2010-01-19, Close, 16.13
# 2010-01-20, Close, 16.07
# 2010-01-21, Close, 15.78
# 2010-01-21, CREATE SELl ORDER, 15.78
# 2010-01-22, SELL EXECUTED, Price: 15.59, Cost: 164.60, Comm 0.16
# 2010-01-22, OPERATION PROFIT, GROSS -8.70, NET -9.02
# 2010-01-22, Close, 15.23
# 2010-01-22, CREATE BUY ORDER, 15.23
# 2010-01-25, BUY EXECUTED, Price: 15.48, Cost: 154.80, Comm 0.15
# 2010-01-25, Close, 15.49
# 2010-01-26, Close, 15.00
# 2010-01-27, Close, 15.41
# 2010-01-28, Close, 14.89
# 2010-01-29, Close, 14.24
# 2010-02-01, Close, 15.34
# 2010-02-01, CREATE SELl ORDER, 15.34
# 2010-02-02, SELL EXECUTED, Price: 15.28, Cost: 154.80, Comm 0.15
# 2010-02-02, OPERATION PROFIT, GROSS -2.00, NET -2.31
# 2010-02-02, Close, 15.49
# 2010-02-03, Close, 15.62
# 2010-02-04, Close, 14.72
# 2010-02-05, Close, 15.01
# 2010-02-08, Close, 14.98
# 2010-02-09, Close, 14.86
# 2010-02-09, CREATE BUY ORDER, 14.86
# 2010-02-10, BUY EXECUTED, Price: 14.96, Cost: 149.60, Comm 0.15
# 2010-02-10, Close, 15.15
# 2010-02-11, Close, 15.84
# 2010-02-12, Close, 16.06
# 2010-02-16, Close, 16.35
# 2010-02-17, Close, 16.51
# 2010-02-18, Close, 15.43
# 2010-02-18, CREATE SELl ORDER, 15.43
# 2010-02-19, SELL EXECUTED, Price: 15.36, Cost: 149.60, Comm 0.15
# 2010-02-19, OPERATION PROFIT, GROSS 4.00, NET 3.70
# 2010-02-19, Close, 15.35
# 2010-02-19, CREATE BUY ORDER, 15.35
# 2010-02-22, BUY EXECUTED, Price: 15.41, Cost: 154.10, Comm 0.15
# 2010-02-22, Close, 15.37
# 2010-02-23, Close, 15.00
# 2010-02-24, Close, 15.32
# 2010-02-25, Close, 15.18
# 2010-02-26, Close, 14.99
# 2010-03-01, Close, 15.59
# 2010-03-01, CREATE SELl ORDER, 15.59
# 2010-03-02, SELL EXECUTED, Price: 15.73, Cost: 154.10, Comm 0.16
# 2010-03-02, OPERATION PROFIT, GROSS 3.20, NET 2.89
# 2010-03-02, Close, 15.59
# 2010-03-03, Close, 15.39
# 2010-03-04, Close, 15.42
# 2010-03-05, Close, 15.89
# 2010-03-08, Close, 15.66
# 2010-03-09, Close, 16.24
# 2010-03-10, Close, 16.28
# 2010-03-11, Close, 15.91
# 2010-03-12, Close, 15.97
# 2010-03-15, Close, 15.88
# 2010-03-16, Close, 16.44
# 2010-03-17, Close, 16.75
# 2010-03-18, Close, 16.16
# 2010-03-19, Close, 15.97
# 2010-03-19, CREATE BUY ORDER, 15.97
# 2010-03-22, BUY EXECUTED, Price: 15.76, Cost: 157.60, Comm 0.16
# 2010-03-22, Close, 16.22
# 2010-03-23, Close, 16.56
# 2010-03-24, Close, 16.00
# 2010-03-25, Close, 16.05
# 2010-03-26, Close, 16.05
# 2010-03-29, Close, 16.25
# 2010-03-29, CREATE SELl ORDER, 16.25
# 2010-03-30, SELL EXECUTED, Price: 16.44, Cost: 157.60, Comm 0.16
# 2010-03-30, OPERATION PROFIT, GROSS 6.80, NET 6.48
# 2010-03-30, Close, 16.32
# 2010-03-31, Close, 16.10
# 2010-04-01, Close, 15.94
# 2010-04-01, CREATE BUY ORDER, 15.94
# 2010-04-05, BUY EXECUTED, Price: 16.04, Cost: 160.40, Comm 0.16
# 2010-04-05, Close, 16.18
# 2010-04-06, Close, 15.78
# 2010-04-07, Close, 15.88
# 2010-04-08, Close, 15.62
# 2010-04-09, Close, 15.72
# 2010-04-12, Close, 16.01
# 2010-04-12, CREATE SELl ORDER, 16.01
# 2010-04-13, SELL EXECUTED, Price: 16.08, Cost: 160.40, Comm 0.16
# 2010-04-13, OPERATION PROFIT, GROSS 0.40, NET 0.08
# 2010-04-13, Close, 16.34
# 2010-04-14, Close, 16.55
# 2010-04-15, Close, 16.67
# 2010-04-16, Close, 15.79
# 2010-04-19, Close, 15.72
# 2010-04-19, CREATE BUY ORDER, 15.72

# %%
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Final Portfolio Value: 1000099.00

# %%
cerebro.plot(iplot=False)
plt.show()
